# %% [markdown]
# The primary objective of this exploratory data analysis (EDA) project is to uncover insights from Hillary Clinton's emails using NLP and statistical methods. The project aims to:
#
# 1) Identify the common topics discussed using TF-IDF
# 2) Understand the network of senders and recipients to identify key figures and their relationships.
#    Explore the frequency and patterns of email communications over time.

# %% [markdown]
# **Data Cleaning and Preprocessing:** This initial step involves cleaning the dataset for analysis, including handling missing values, removing duplicates, and standardizing date formats. NLP-specific preprocessing will also be necessary, such as tokenization, removing stopwords, and lemmatization.
#
# **Exploratory Data Analysis:** Employing statistical and visualization techniques to summarize the dataset's main characteristics. This includes analyzing the distribution of emails over time, the most frequent senders and recipients, and the length of emails.
#
# **TF-IDF:** Using NLP techniques such as TF-IDF or count vectorization generate a list of the five TF-IDF terms that best describe the emails. This can provide insights into the main topics and themes discussed in the emails.
#
# **Temporal Analysis:** Investigate how email communications change over time, identify any patterns or anomalies in the volume of emails sent and received, and correlate these with external events or timelines.

# %% [markdown]
# **Imports**

# %%
import pandas as pd
import numpy as np
import sklearn
# %pip install gensim
import gensim as gensim
import matplotlib.pyplot as plt
# %pip install nltk
import nltk
from nltk.tokenize import word_tokenize
from nltk.stem.porter import *
from nltk.corpus import stopwords
import string
# Out:
# Requirement already satisfied: gensim in c:\users\rija\appdata\local\programs\python\python38\lib\site-packages (4.3.2)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\rija\appdata\local\programs\python\python38\lib\site-packages (from gensim) (1.23.5)
# Requirement already satisfied: scipy>=1.7.0 in c:\users\rija\appdata\local\programs\python\python38\lib\site-packages (from gensim) (1.10.1)
# Requirement already satisfied: smart-open>=1.8.1 in c:\users\rija\appdata\local\programs\python\python38\lib\site-packages (from gensim) (6.4.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.3.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
#
# [notice] A new release of pip is available: 23.3.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: nltk in c:\users\rija\appdata\local\programs\python\python38\lib\site-packages (3.8.1)
# Requirement already satisfied: click in c:\users\rija\appdata\local\programs\python\python38\lib\site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in c:\users\rija\appdata\local\programs\python\python38\lib\site-packages (from nltk) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\rija\appdata\local\programs\python\python38\lib\site-packages (from nltk) (2023.12.25)
# Requirement already satisfied: tqdm in c:\users\rija\appdata\local\programs\python\python38\lib\site-packages (from nltk) (4.66.1)
# Requirement already satisfied: colorama in c:\users\rija\appdata\local\programs\python\python38\lib\site-packages (from click->nltk) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# **Read csv file**

# %%
emails = pd.read_csv("Emails.csv")

# %% [markdown]
# **(1a) Data Cleaning: General**

# %% [markdown]
# Handling Missing Values

# %%
emails['ExtractedBodyText'].fillna('null', inplace=True)

# %% [markdown]
# **Removing Duplicates**

# %% [markdown]
# There are no complete duplicates, which is good.

# %%
# Detect and display duplicate rows based on all columns
duplicate_rows = emails[emails.duplicated()]

# %%
duplicate_rows
# Out:
# Empty DataFrame
# Columns: [Id, DocNumber, MetadataSubject, MetadataTo, MetadataFrom, SenderPersonId, MetadataDateSent, MetadataDateReleased, MetadataPdfLink, MetadataCaseNumber, MetadataDocumentClass, ExtractedSubject, ExtractedTo, ExtractedFrom, ExtractedCc, ExtractedDateSent, ExtractedCaseNumber, ExtractedDocNumber, ExtractedDateReleased, ExtractedReleaseInPartOrFull, ExtractedBodyText, RawText]
# Index: []
#
# [0 rows x 22 columns]

# %% [markdown]
# Duplicate Body Text: FYI and ok with varying case are the most commonly repeated messages.

# %%
# Exclude rows with 'null' in 'ExtractedBodyText'
filtered_emails = emails[emails['ExtractedBodyText'] != 'null']

# Detect and display duplicate rows based on the 'ExtractedBodyText' column
duplicate_body = filtered_emails[filtered_emails.duplicated(subset='ExtractedBodyText', keep=False)]
duplicate_body.head(10)
# Out:
#     Id  DocNumber                                    MetadataSubject  \
# 2    3  C05739547                                      CHRIS STEVENS
# 8    9  C05739562                                SECRETARY'S REMARKS
# 9   10  C05739563                                      MORE ON LIBYA
# 11  12  C05739565                                      MORE ON LIBYA
# 12  13  C05739567                                                HEY
# 22  23  C05739580          H: MAGARIAF ON ATTACK ON US IN LIBYA. SID
# 24  25  C05739586                                 PROPOSED QUAD DEAL
# 26  27  C05739588                                      MORE ON LIBYA
# 27  28  C05739589                                       AMB STEVENS
# 30  31  C05739592  QUICK SUMMARY OF POTUS CALLS TO PRESIDENTS OF ...
#
#            MetadataTo       MetadataFrom  SenderPersonId  \
# 2                  ;H    Mills, Cheryl D            32.0
# 8                   H  Sullivan, Jacob J            87.0
# 9                   H                NaN             NaN
# 11                  H                NaN             NaN
# 12                  H  Sullivan, Jacob J            87.0
# 22  Russorv@state.gov                  H            80.0
# 24                  H  Sullivan, Jacob J            87.0
# 26                  H  Sullivan, Jacob J            87.0
# 27                  H    Mills, Cheryl D            32.0
# 30                  H  Sullivan, Jacob J            87.0
#
#              MetadataDateSent       MetadataDateReleased  \
# 2   2012-09-12T04:00:00+00:00  2015-05-22T04:00:00+00:00
# 8   2012-09-12T04:00:00+00:00  2015-05-22T04:00:00+00:00
# 9   2012-09-12T04:00:00+00:00  2015-05-22T04:00:00+00:00
# 11  2012-09-12T04:00:00+00:00  2015-05-22T04:00:00+00:00
# 12  2012-09-12T04:00:00+00:00  2015-05-22T04:00:00+00:00
# 22  2012-09-12T04:00:00+00:00  2015-05-22T04:00:00+00:00
# 24  2011-03-23T04:00:00+00:00  2015-05-22T04:00:00+00:00
# 26  2012-09-13T04:00:00+00:00  2015-05-22T04:00:00+00:00
# 27  2012-09-13T04:00:00+00:00  2015-05-22T04:00:00+00:00
# 30  2012-09-13T04:00:00+00:00  2015-05-22T04:00:00+00:00
#
#                                       MetadataPdfLink MetadataCaseNumber  ...  \
# 2   DOCUMENTS/HRC_Email_1_296/HRCH2/DOC_0C05739547...       F-2015-04841  ...
# 8   DOCUMENTS/HRC_Email_1_296/HRCH2/DOC_0C05739562...       F-2015-04841  ...
# 9   DOCUMENTS/HRC_Email_1_296/HRCH2/DOC_0C05739563...       F-2015-04841  ...
# 11  DOCUMENTS/HRC_Email_1_296/HRCH2/DOC_0C05739565...       F-2015-04841  ...
# 12  DOCUMENTS/HRC_Email_1_296/HRCH2/DOC_0C05739567...       F-2015-04841  ...
# 22  DOCUMENTS/HRC_Email_1_296/HRCH2/DOC_0C05739580...       F-2015-04841  ...
# 24  DOCUMENTS/HRC_Email_1_296/HRCH1/DOC_0C05739586...       F-2015-04841  ...
# 26  DOCUMENTS/HRC_Email_1_296/HRCH2/DOC_0C05739588...       F-2015-04841  ...
# 27  DOCUMENTS/HRC_Email_1_296/HRCH2/DOC_0C05739589...       F-2015-04841  ...
# 30  DOCUMENTS/HRC_Email_1_296/HRCH2/DOC_0C05739592...       F-2015-04841  ...
#
#            ExtractedTo                             ExtractedFrom  \
# 2                   B6       Mills, Cheryl D <MillsCD@state.gov>
# 8                  NaN   Sullivan, Jacob J <Sullivanli@stategov>
# 9                  NaN                                       NaN
# 11                 NaN                                       NaN
# 12                 NaN  Sullivan, Jacob J <SullivanJJ@state.gov>
# 22  'Russorv@stategov'                H <hrod17©clintonemaiLcom>
# 24                 NaN  Sullivan, Jacob .1 ‹Sullivann@state.gov>
# 26                 NaN  Sullivan, Jacob I <Sullivanit@state,gov›
# 27                 NaN        Mills, Cheryl 0 <MillsCD@stategov>
# 30                 NaN           McDonough, Denis R. (mailto: B6
#
#                                           ExtractedCc  \
# 2                                        Abedin, Huma
# 8                                                 NaN
# 9                                                 NaN
# 11                                                NaN
# 12                                                NaN
# 22                                                NaN
# 24  McEldowney, Nancy E; Heffern, John A; Spence, ...
# 26                                                NaN
# 27  Macmanus, Joseph E (S[)ialAssistants; Abbaszad...
# 30                                                NaN
#
#                          ExtractedDateSent ExtractedCaseNumber  \
# 2   Wednesday, September 12, 2012 11:52 AM        F-2015-04841
# 8    Wednesday, September 12, 2012 6:08 PM        F-2015-04841
# 9                                      NaN        F-2015-04841
# 11                                     NaN        F-2015-04841
# 12     Wednesday, September 12 2012 700 PM        F-2015-04841
# 22  Wednesday, September 12, 2012 11:30 PM        F-2015-04841
# 24      Wednesday, March 23, 2011 09:10 PM        F-2015-04841
# 26    Thursday, September 13, 2012 2:31 AM        F-2015-04841
# 27   Wednesday, September 12, 2012 8:52 AM        F-2015-04841
# 30    Thursday, September 13, 2012 1:26 PM        F-2015-04841
#
#    ExtractedDocNumber ExtractedDateReleased ExtractedReleaseInPartOrFull  \
# 2           C05739547            05/14/2015              RELEASE IN PART
# 8           C05739562            05/13/2015              RELEASE IN FULL
# 9           C05739563            05/13/2015              RELEASE IN PART
# 11          C05739565            05/13/2015              RELEASE IN PART
# 12          C05739567            05/13/2015              RELEASE IN PART
# 22          C05739580            05/13/2015              RELEASE IN PART
# 24          C05739586            05/13/2015              RELEASE IN PART
# 26          C05739588            05/13/2015              RELEASE IN PART
# 27          C05739589            05/13/2015              RELEASE IN PART
# 30          C05739592            05/13/2015              RELEASE IN PART
#
#                                     ExtractedBodyText  \
# 2                                                 Thx
# 8                                                 FYI
# 9   B6\r\nWednesday, September 12, 2012 6:16 PM\r\...
# 11  B6\r\nWednesday, September 12, 2012 6:16 PM\r\...
# 12                                                Fyi
# 22                                         Pis print.
# 24                                                 B5
# 26                                           Will do.
# 27                               Remind me to discuss
# 30                                                FYI
#
#                                               RawText
# 2   UNCLASSIFIED\r\nU.S. Department of State\r\nCa...
# 8   UNCLASSIFIED\r\nU.S. Department of State\r\nCa...
# 9   UNCLASSIFIED\r\nU.S. Department of State\r\nCa...
# 11  UNCLASSIFIED\r\nU.S. Department of State\r\nCa...
# 12  UNCLASSIFIED\r\nU.S. Department of State\r\nCa...
# 22  UNCLASSIFIED\r\nU.S. Department of State\r\nCa...
# 24  UNCLASSIFIED\r\nU.S. Department of State\r\nCa...
# 26  UNCLASSIFIED\r\nU.S. Department of State\r\nCa...
# 27  UNCLASSIFIED\r\nU.S. Department of State\r\nCa...
# 30  UNCLASSIFIED\r\nU.S. Department of State\r\nCa...
#
# [10 rows x 22 columns]

# %%
# Exclude rows with 'null' in 'ExtractedBodyText'
filtered_emails = emails[emails['ExtractedBodyText'] != 'null']

# Group by 'ExtractedBodyText' and count occurrences
duplicate_counts = filtered_emails['ExtractedBodyText'].value_counts()

# Create a DataFrame with 'ExtractedBodyText' and its corresponding counts
duplicate_counts_df = pd.DataFrame({'ExtractedBodyText': duplicate_counts.index, 'Occurrences': duplicate_counts.values})

# Display the DataFrame
duplicate_counts_df.head(10)
# Out:
#   ExtractedBodyText  Occurrences
# 0               Fyi          174
# 1               FYI          156
# 2                Ok           76
# 3               fyi           64
# 4               Ok.           39
# 5        Pls print.           32
# 6          Will do.           30
# 7               Yes           15
# 8        Pis print.           14
# 9              FYI.           13

# %% [markdown]
# **Standardizing Date Formats**

# %% [markdown]
# ExtractedDateSent was standardized because it needs to understand patterns in the volume of emails sent.

# %%
emails['ExtractedDateSent'] = emails['ExtractedDateSent'].replace('null', pd.NaT)
emails['ExtractedDateSent'] = pd.to_datetime(emails['ExtractedDateSent'], errors='coerce', infer_datetime_format=True)
emails.set_index('ExtractedDateSent', inplace=True)
# Out:
# C:\Users\Rija\AppData\Local\Temp\ipykernel_36220\3557722988.py:2: UserWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   emails['ExtractedDateSent'] = pd.to_datetime(emails['ExtractedDateSent'], errors='coerce', infer_datetime_format=True)

# %% [markdown]
# **(1b) NLP Specific Processing:** Tokenization, Removing Stopwords and Lemmatization

# %% [markdown]
# The lemmatizer is adapted from class notes. There may be a way to integrate the bigrams with the lemmatizer.

# %%
# We can use NLTK to tokenize and lemmatize our text
nltk.download('stopwords')

# Create instances of the stemmer
stemmer = PorterStemmer()

# For stopwords we will add punctuation
punct = list(string.punctuation) + list(string.digits) 
# null = list('null')  #neither of these methods
stop_words = stopwords.words('english') + punct + ['null']
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Rija\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Create a list to store processed data
corpus = []

# Iterate over the rows in the 'emails' DataFrame
for index, row in emails.iterrows():
    # Extract ID and content from the DataFrame
    email_id = row['Id']
    email_content = row['ExtractedBodyText']
    
    # Tokenize and lemmatize the text
    tokens = word_tokenize(email_content)
    tokens = [stemmer.stem(token.lower()) for token in tokens if token.isalpha()]
    
    # Remove stopwords
    tokens = [token for token in tokens if token not in stop_words]
    
    # Append ID and processed text to the corpus list
    corpus.append([email_id, ' '.join(tokens)])

# %%
corpus
# Out:
# [[1, ''],
#  [2,
#   'thursday march pm h latest syria aid qaddafi sid hrc memo syria aid libya hrc memo syria aid libya march hillari'],
#  [3, 'thx'],
#  [4, ''],
#  [5,
#   'h friday march pm huma abedin fw h latest syria aid qaddafi sid hrc memo syria aid libya pi print'],
#  [6,
#   'pi print h clintonernailcom wednesday septemb pm fw meet extremist behind film spark deadli riot meat sent wednesday septemb pm subject meet right wing extremist behind film spark deadli riot sent verizon wireless lte droid depart state case doc date state dept produc hous select benghazi comm subject agreement sensit inform redact foia waiver'],
#  [7, ''],
#  [8,
#   'h friday march pm huma abedin fw h latest syria aid qaddafi sid hrc memo syria aid libya pi print'],
#  [9, 'fyi'],
#  [10,
#   'wednesday septemb pm fwd libya libya sept send direct sent verizon wireless lte druid'],
#  [11, 'fyi'],
#  [12,
#   'wednesday septemb pm fwd libya libya sept send direct sent verizon wireless lte druid'],
#  [13, 'fyi'],
#  [14,
#   'slaughter sunday march pm jacob mill cheryl reinesp stategov abedin hurtl piec libya nfz appear nyt page tomorrow want make sure head slaughter professor polit intern affair princeton slaughter presid obama say noos tighten around muammar fact tighten around libyan rebel colonel qaddafi make world dither steadili retak unit state europ tempor zone organ islam confer gulf cooper council arab leagu call unit nation secur council author one oppon flight zone put forth five main argument none closer examin hold interest wesley clark argu libya doe sell much oil unit state american want support democrat movement region alreadi iraq afghanistan frame thi issu term oil exactli arab popul inde much world expect whi cynic profess support democraci human right chanc support new begin muslim world new begin account govern provid servic opportun citizen way could dramat decreas support terrorist group violent extrem hard imagin someth strateg interest mani thought comment includ al jazeera director gener wadah khanfar argu import arab spring come arab themselv thi perspect western militari intervent play right qaddati hand allow broadcast pictur western bomb fall arab civilian argument import must weigh appeal libyan opposit fighter ask intern help astonishingli support zone govern kept popul quiescent hold specter foreign intervent assum zone impos intern coalit includ arab state opportun establish new narr western support arab democrat depart state case doc date state dept produc hous select benghazi comm subject agreement sensit inform redact foia waiver depart state case doc date state dept produc hous select benghazi comm subject agreement sensit inform redact foia waiver wo work unit state ambassador nato ivo daaider argu stop colonel qaddafi air forc decis continu inflict damag tank helicopt bomb oil refineri depot hi way retak key town potenti effect zone must also assess term colonel qaddafi calcul hi futur richard downi center strateg intern studi argu although colonel qaddafi cultiv imag ha canni survivor polit manipul year awar debat regard zone time hi militari campaign accordingli also capabl use hi air forc enough gain strateg advantag enough trigger zone intern commun line crater hi runway take hi antiaircraft weapon might well renew hi offer negoti departur doe work know get revolut almost alway follow intern divis among revolutionari expect rosi jeffersonian libya choic uncertainti certainti colonel qaddafi win regim across region conclud forc livay answer protest colonel qaddafi massacr opposit young protest across middl east conclud ask support caus word blink american turn read word june speech lofti promis stand univers human right cring let arm rebel instead comment agre analysi abov say could accomplish goal provid intellig arm opposit would cours much easier us undoubtedli appeal mn obama neat compromis desir help protest desir overrul hi defens secretari reluct particip zone would provid arm disciplin militari rag group brave volunt bare know use weapon need action chang situat ground colonel qaddafi well hi calcul moreov time arm intellig could take effect quit like colonel qaddafi retaken least besieg opposit stronghold unit state immedi ask secur council author zone make clear russia china block resolut blood libyan opposit hand push least abstain bring issu vote soon possibl get resolut work arab leagu quickli assembl intern coalit impos zone secur council fail toact recogn opposit interim nation council legitim libyan govern franc ha done work arab leagu give council ani assist request depart state case doc date state dept produc hous select benghazi comm subject agreement sensit inform redact foia waiver depart state case doc date state dept produc hous select benghazi comm subject agreement sensit inform redact foia waiver ani use forc must care fulli debat debat ha rage week dure almost everi arab countri ha come board call zone colonel qaddafi ha retaken two key citi move toward three time act depart  ...
#  [15,
#   'randolph lawrenc sent wednesday septemb pm mill cheryl subject dri eye nea includ mine remark realli move chriswa amaz man huge loss know wa libya befor come almost ten year never work calm cool head funni diplomat made seem realli even one hardest place work world'],
#  [16,
#   'ask attend svtc today embassi tripoli becaus first met mani staff went malta tripoli reopen embassi today death hit much harder would guess alway proud serv never word meaning today svtc everi day tenur ha extraordinari none today thank inspir leadership exampl ever harold depart state case doc date state dept produc hous select benghazi comm subject agreement sensit inform redact foia waiver'],
#  [17, 'hope see pictur kamala sent'],
#  [18, 'anoth photo'],
#  [19, 'thi nice'],
#  [20,
#   'amaz sullivan jacob j sullivanii state gov wednesday septemb pm sherman wendi r h mill cheryl nuland victoria j rein philipp youth libya'],
#  [21,
#   'h wednesday septemb pm esullivanjj fw fwd libya libya sept docx get thi around asap'],
#  [22, 'pi print h wednesday septemb pm fw fwd libya libya sept'],
#  [23, 'pi print'],
#  [24, 'follow flag follow flag statu flag info'],
#  [25, ''],
#  [26,
#   'sidney blumenth thursday septemb h magariaf privat reax sent memo sid hre memo magariaf privat reax septemb hillari'],
#  [27, ''],
#  [28, 'remind discuss'],
#  [29,
#   'http editor note stephen prothero boston univers religion scholar author american bibl word unit divid defin nation regular cnn belief blog contributor stephen prothero special cnn make attack consul egypt libya yemen death four american includ ambassador libya chri steven depend mean perspect storm embassi take american flag egypt replac black flag read god allah moham hi messeng wa act justic behalf one true faith american come accord thi view becaus american wrong side clash civil west muslim world creation video iron entitl innoc muslim produc thought american provid catalyst excus protest whi muslim sensit portray prophet moham american oper differ perspect assault wa unjust cowardli attack among thing rule law institut diplomaci right free speech libyan deputi prime minist mustafa abushagur gave voic thi perspect said twitter condemn barbar attack strongest possibl term thi attack america libya free peopl everywher sought justifi thi viciou behavior respons inflammatori materi post internet secretari state hillari clinton ad unit state deplor ani intent effort denigr religi belief commit religi toler goe back veri begin nation commenc speech kenyon colleg later publish thi water novelist david foster wallac urg student scrutin natur basic put center world thi unconsci default set foster sort blind certainti manifest arrog atheism fundament alik wallac said point educ shake us default set begin see thing perspect follow cnn belief blog twitter depart state case doc date state dept produc hous select benghazi comm subject agreement sensit inform redact foia waiver depart state case doc date state dept produc hous select benghazi comm subject agreement sensit inform redact foia waiver wallac focus hi speech individu hi critiqu appli well anoth default set thi one cultur natur tendenc understand world perspect accord storm embassi innoc muslim wa made individu whoever shadowi sam bacil may may wa made anamerican moreov accord thi groupthink american group respons sin individu american make perfect sens strike embassi personnel issu statement befor protest turn deadli condemn continu effort misguid individu hurt religi feel muslim condemn effort offend believ religion cnn belief blog faith angl behind biggest stori meanwhil shadowi figur produc distribut innoc muslim imprison groupthink gather world muslim categori evil islam empir film doe depict moham con man philander pedophil portray hi follow dupe unfortun event recent day done noth jar alleg produc thi default set question hi film aftermath libyan egyptian attack man identifi sam bacil reportedli told wall street journal islam cancer need kenyon colleg degre see thi viciou cycl provoc violenc fuel need moral relativist see take two side keep run american justli proud first amend protect freedom speech religion believ kill oppon name god nation far greater offens offend ignor movi nonetheless root problem display view wallac denounc blind certainti world divid first foremost along religi nation line muslim christian hindu isra american egyptian neither divid secularist peopl faith new atheist partisan religion real red line modem world divid certain uncertain tragic event recent day produc distribut thi hate movi stand side thi line killer innoc libya egypt group possess unholi spirit blind certainti unacquaint complex contradict life earth cloud unknow hover everi major religion great religi thinker judaism christian islam alway knew enough know know everyth knew differ etern decre god abraham thought ordinari peopl knew short god alon charg creat destroy world discrimin along way real illusori killer libya forgotten produc distributor innoc islam opinion express thi commentari sole stephen prothero depart state case doc date state dept produc hous select benghazi comm subject agreement sensit inform redact foia waiver depart state case doc date state dept produc hous select benghazi comm subject agreement sensit inform redact foia waiver cnn belief blog faith angl b ...
#  [30, 'see note'],
#  [31, 'fyi'],
#  [32, 'embassi yemen'],
#  [33,
#   'sunday march pm h lot new intel possibl libyan collaps sid hic memo lot new intel possibl immin collaps hrc memo lot new intel possibl immin collaps march hillari sid lot new intel libyan armi possibl verg collaps latest dure even march individu direct access militari committe nation libyan council nlc state confid rebel forc continu organ commun problem moral ha improv drastic believ libyan armi verg collaps attack alli air naval forc libyan armi troop begun desert rebel side increas number rebel make effort togeet troop fellow libyan effort encourag addit defect sourc comment speak strict confid one rebel command state hi troop continu summarili execut foreign mercenari captur fight time colonel khalifa ha reportedli join rebel command structur effort help organ rebel forc haftar wa command libyan nation armi na man forc troop base chad current presid idryss debi overthrew chadian presid hussein habr fall assist libyan french troop haftar hi troop lie cotaatri central africa mani includ haftar later settl unit state extrem sensit sourc ad rebel receiv direct assist train small number egyptian special forc unit french british special oper troop work base egypt along libyan border troop overse transfer weapon suppli rebel depart state case doc date state dept produc hous select benghazi comm subject agreement sensit inform redact foia waiver depart state case doc date state dept produc hous select benghazi comm subject agreement sensit inform redact foia waiver sourc comment rebel move back lost march fight use alli air cover confid move tripoli district matter day one rebel sourc report reliabl intellig peopl evacu qaddafi hometown sirt anticip captur rebel sirt locat tripoli benghazi loss psycholog blow qaddal separ sensit european sourc state strict confid french militari command anticip complet collaps libyan militari command control structur next week offic experi libyan armi dure invas chad late state libyan troop perform well concentr fire troop arm modern weapon thi sourc also note inform tripoli ha becom increasingli difficult obtain report death among qaddafi senior secur offici includ mansour daw libyan leader may experienc health problem unfortun european intellig servic unabl confirm discredit report thi situat ha becom increasingli frustrat french presid nicola sarkozi accord knowledg individu press franc emerg thi crisi princip foreign alli ani new govern take power sarkozi also concern continu report group libyan fight group al islam maghreb aqim infiltr nlc militari command accordingli ask sociologist ha long establish tie israel syria nation middl east use hi contact determin level influenc aqim terrorist group insid nlc sarkozi also ask report set clear pictur role muslim brotherhood rebel leadership sourc note french diplomat intellig offic egypt contact follow rebel figur benghazi qaddafi former head protocol along mousa kousa wa consid libyan leader loyal follow noun current live franc abdallah colonel faraj boukhri fathi gener abdelfateh youni command rebel forc sourc comment senior european secur offici caution aqim watch develop libya element organ touch tribe southeastern part countri offici concern libya franc western european countri must move quickli ensur new govern doe allow aqua set small autonom local caliph oil ga produc region southeastern libya knowledg sourc add insurg follow weapon stockpil benghazi mm mortar gpz type machin gun machin gun mount vehicl batteri type zsu well system manpad type sam tank type depart state case doc date state dept produc hous select benghazi comm subject agreement sensit inform redact foia waiver depart state case doc date state dept produc hous select benghazi comm subject agreement sensit inform redact foia waiver possibl fix wing aircraft light transporthnedim helicopt seemingli endless suppli assault rifl ammunit even system zsu french british egyptian special forc troop train rebel insid western egypt limit degre western suburb benghazi sourc comment s ...
#  [34,
#   'pi print sullivan jacob mailto sullivanjj sent thursday septemb pm subject fw quick summari potu call presid libya egypt fyi'],
#  [35, 'fyi'],
#  [36, ''],
#  [37,
#   'depart privat resid en rout state depart arriv state depart presidenti daili brief secretari offic daili senior staff meet secretari confer room group photo wffemal militari offic africa treati ksom floor close press offici photograph onli staff monica ws carson greet escort treati room peopl attend consecut french portugues interpret tun weekli meet ambassador susan rice secretari offic award present deputi execut secretari pam quanrud secretari outer offic close press offici photograph onli staff rob lanta peopl expect present superior honor award pam meet secretari mike posner cheryl secretari outer offic wfwendi jake wh meet secretari outer offic depart state depart en rout white hous arriv white hous meet pm white hous situat room pm depart white hous en rout andrew air forc base pm arriv andrew air forc base pm ceremoni return remain depart pm colleagu benghazi libya andrew air forc base press scenario tbd staff monica pm depart andrew air forc base en rout state depart pm arriv state depart pm offic time tbd secretari offic tbd depart state depart en rout andrew air forc base tbd arriv andrew air forc base tbd depart andrew air forc base via air forc aircraft tail en rout white plain ny tbd arriv westchest counti airport depart state case doc date state dept produc hous select benghazi comm subject agreement sensit inform redact foia waiver depart state case doc date state dept produc hous select benghazi comm subject agreement sensit inform redact foia waiver tbd depart westchest counti aim ea rout privat resid arriv privat resid depart state case doc date state dept produc hous select benghazi comm subject agreement sensit inform redact foia waiver'],
#  [38, ''],
#  [39, 'give credit inspir peac protest'],
#  [40,
#   'depart state case doc date state dept produc hous select benghazi comm subject agreement sensit inform redact foia waiver'],
#  [41, 'fyi'],
#  [42, 'deserv great teamwork great leadership'],
#  [43, 'pi print'],
#  [44, 'gate said sunday show'],
#  [45, 'fyi'],
#  [46, 'lyi wa refer libyan arm rebel breathless silli'],
#  [47,
#   'http monday oct edt gop octob surpris call jimmi carter strategi exploit libya attack paint obama weak terror credit accord highli reliabl sourc mitt romney presid barack obama prepar first presidenti debat wednesday night top republican oper prime unleash new offens attack obama weak nation secur base part inw ia en regard attack libya kill ambassador chri steven septemb sourc ha knowledg privat convers romney tamp took place washington dc last week said variou time gop strategist refer new oper jimmi carter strategi octob surpris ad plan releas hope would bombshel would make libya obama foreign polici major issu campaign understand come evid obama administr posit intellig wa go terrorist attack intellig sourc describ republican chortl glee obama administr definit intel attack befor happen intellig grade differ way ad sometim b get connect romney campaign tri paint look like obama advanc knowledg attack weak terror said jubil new strategi said intend portray obama helpless jimmi presid equat tragedi libya presid carter fail attempt rescu american hostag iran excit said talk bow would like jimmi carter fail raid feel go give landslid elect sourc howev said lie wa dubiou tactic indic lost touch huge portion elector said sourc declin reveal name gop oper present said top guy parti wa unguard plan convers depart state case doc date state dept produc hous select benghazi comm subject agreement sensit inform redact foia waiver depart state case doc date state dept produc hous select benghazi comm subject agreement sensit inform redact foia waiver describ particip meet consist name tie big republican super pac peopl access nation secur intellig usual karl rove wa present said close rove sourc said wa quit bit oper simpli reveal intellig regard libya declin discuss describ second phase oper howev alreadi evid first phase oper underway wednesday septemb fox news karl rove call obama reaction happen libya inexplic ad obama intent campaign meet hi respons went warn obama polici libya endang regard iran astonish rove said project weak need project strength similarli former new york mayor rudolph giuliani gop presidenti hope becam known mayor follow rove critic obama attack libya thi deliber attempt cover truth administr claim want transpar histori told fox news worst kind kind involv nation secur thi involv slaughter four american giuliani ad obama white hous want dismiss role play becaus seem diminish triumph kill osama bin laden think becaus thi narr defeat said never say word fundamentalist terror want wish away presid wa move asia wa go declar thi great victori unfortun thi terribl act terror interven veri conveni narr likewis bob corker republican senat tennesse describ administr respons terrorist attack libya sunday septemb mitt romney nomine paul ryan join attack think want veri best keep peopl america understand exactli happen expect candor expect transpar particularli relat terror romney said ad ryan whi obama page hi administr offici say thi terrorist attack leav decid whether appar relat develop politico artkl post last night said romney advis divid hovv aggress attack presid obama hi handl event libya one unnam romney advis describ huge gift campaign across board domest econom issu presid obama ha outmatch event said observ event shaper event everywher look outmatch romney advis led media strategist stuart steven want stick economi central issu tell got focu peopl fact econom prospect veri good aid told politico well romney tri sinc clinch nomin end april fail presid better deflect attent bad news romney drive home impact bad news individu voter craig unger new york time bestsel author hous bush hous saud frequent analyst cnn abc radio air america charli rose show nbc today show broadcast outlet ha written new yorker esquir mani public current contribut editor vaniti fair depart state case doc date state dept produc hous select benghazi comm subject agreement sensit inform redact foia waiver'],
#  [48, 'pi let know phil find asap thx'],
#  [49, ''],
#  [50, 'deserv leadership let meant especi love speech'],
#  [51,
#   'sullivan jacob j sullivanjj monday octob pm h romney last gambit got done publish sid'],
#  [52,
#   'one wall worth veri dubiou arm libyan rebel best bet keep pressur side forc diplo solut aryl depart state case doc date state dept produc hous select benghazi comm subject agreement sensit inform redact foia waiver'],
#  [53,
#   'romney ha today wall street journal play steven murder say obama ha put secur risk etc accord politico yesterday wa intern argument within romney campaign libya obvious neocon rove orient faction ed gillespi rove surrog romney campaign advis beat stuart steven romney careen tactic tactic hope someth catch would surpris see romney rais specter muslim brotherhood charg egypt libya bogeyman heard thi within last week'],
#  [54,
#   'sidney blumenthat friday septemb pm h morsi privat convers today sid hrc memo morsi privat convers hillari'],
#  [55,
#   'remark thi afternoon andrew wonder thank much institut sad day sent hi side note visit tajordan iraq look forward catch enjoy weekend meantim bill depart state case doc date state dept produc hous select benghazi comm subject agreement sensit inform redact foia waiver'],
#  [56,
#   'info sidney blumenth mailto sent monday octob pm h subject romney last gambit got done arid publish sid romney ha today wall street journal play steven murder say obama ha put secur risk etc accord politico yesterday wa intern argument within romney campaign libya obvious neocon rove orient faction ed gillespi rove surrog romney campaign advis beat stuart steven romney careen tactic tactic hope someth catch would surpris see romney rais specter muslim brotherhood charg egypt libya bogeyman heard thi within last week'],
#  [57, ''],
#  [58,
#   'thi pretti uncompel piec ask cours bias mitt romney new cours middl east restor three sinew american influenc econom strength militari strength strength valu disturb develop sweep across greater middl east syria ten thousand innoc peopl slaughter egypt muslim brotherhood ha come power countri peac treati israel hang balanc libya ambassador wa murder terrorist attack embassi throughout region storm violent protest iran ayatollah continu move full tilt toward capabl promis annihil israel develop presid obama say mere bump road major issu put secur risk yet amid thi upheav countri seem merci event rather shape move direct protect peopl alli danger middl east descend chao iran move toward nuclear breakout israel secur compromis america could pull maelstrom still time address threat requir new strategi toward middl east first step understand got sinc world war ii america ha leader free world uniqu earn role conquest promot human right free market rule law alli ourselv countri expand prosper trade keep peac maintain militari second none recent year presid obama ha allow leadership atrophi economi stuck recoveri bare deserv name nation debt ha risen record level militari test decad war face devast cut thank budgetari game play white hous final valu presid think weak win favor adversari fail maintain element influenc step away alli presid obama ha heighten prospect conflict instabl doe understand american polici lack resolv provok aggress encourag disord middl east case point arab spring present opportun help move million peopl oppress freedom also present grave risk need strategi success presid offer none seek downplay signific calam past week incomprehens afflict presid polici toward israel presid began hi term explicit polici creat daylight two countri recent downgrad israel closest alli middl east onli one closest alli diplomat messag receiv clearli israel adversari alik dismiss israel concern iran mere nois prefer block time israel need america stand declin meet prime minist benjamin netanyahu thi period uncertainti need appli coher strategi support partner middl govern individu share valu thi mean restor credibl iran say iranian region instabl come unaccept ayatollah must made believ us mean place daylight unit state israel mean use full spectrum soft power encourag liberti opportun long known onli corrupt oppress digniti work abil steer cours live best altern extrem thi middl east polici undermin unless restor three sinew influenc econom strength militari strength strength valu requir veri differ set polici presid obama pursu depart state case doc date state dept produc hous select benghazi comm subject agreement sensit inform redact foia waiver depart state case doc date state dept produc hous select benghazi comm subject agreement sensit inform redact foia waiver centuri becam american centuri becaus steadfast defens freedom made pain sacrific necessari defeat totalitarian guis defend ourselv alli paid price treasur soldier never came home challeng differ centuri anoth american centuri need leader understand keep peac requir american strength dimens romney republican padi candid presid version thi articl appear octob page edit wallstreet journal headlin new cours middl east'],
#  [59,
#   'fyi take care job prom rhode benjamin sent wednesday march pm sullivan jacob rein philipp subject fin statement press secretari'],
#  [60, ''],
#  [61,
#   'state dept produc hous select benghazi comm subject agreement sensit inform redact foia waiver releas part slaughter friday april gorgeou pie front page nwt bic send arm societi gener particularli disorgan fragment result violenc boy like play gun trust mother son say object french increas pressur gaddafi tribal societi conflict repress long ad even weapon doe make sens obvious get weapon place nb awash weapon wrote someth new york review book thi week build farewel remark think like send weekend read'],
#  [62, 'pi print h wednesday octob pm fw fwd benghazi wa obama call'],
#  [63, ''],
#  [64, ''],
#  [65,
#   'pa clip mailtotaclip sent saturday octob ds pa media shore rhonda h atchison mark c moe grace coordin mill cheryl tow nora f pg subject daili beast diplomat fire person interest unit state un ambassador susan rice oct iloo edt lesli gelb diplomat fire presidenti campaign drown boredom comment desper search news prefer new victim brighten day along came susan rice coupl sunday ago ambassador made mistak appear talk show insist attack consul benghazi libya wa spontan rather terrorist plot would thought said pope wa mormon came washington dagger lie wa shill benghazi wa spontan event wa work al qaeda offshoot white hous fumbl key intellig inform wa tri cover unforgiv mistak rice wa cover presid reward would obama nomin succeed hillari clinton secretari state commentariat immedi roll plan nail rice obama team wall peter king grand inquisitor republican hous repres pledg investig hold hear said commentariat would end rice hope becom new hillari depart state case doc date state dept produc hous select benghazi comm subject agreement sensit inform redact foia waiver depart state case doc date state dept produc hous select benghazi comm subject agreement sensit inform redact foia waiver let take unfashion step back examin fact rice make spontan stori hand white hous conspir got daili intellig brief given presid daili intel report told veri stori rice repeat publicli benghazi mob form less mainli reaction american video cartoon sacr muslim figur extremist took advantag kill includ ambassador christoph steven rice make stori problem wa rice wa inevit complic intellig process mistak wa take initi intellig face valu white hous biiefer made error repeat daili beast intellig briefer told knew veri well contradictori inform would appear soon enough alway doe sure cia addit intel start begun sift commun intercept satellit photo human report alway take time sort fact fiction find consist thread seemingli thi gossam inform take shape meantim rice still veri much run job fogg bottom along senat john kerri nsc advis tom donilon former diplomat nichola burn harvard wa obama earliest loyalist crowd still like despit lacklust report perform smear though flatli inaccur wo help either help importantli flag obama first debat hunt benghazi culprit depart state case doc date state dept produc hous select benghazi comm subject agreement sensit inform redact foia waiver'],
#  [66, 'chri steven go'],
#  [67, 'wa suppos go today check'],
#  [68, 'pi print h friday septemb pm russorv fw cnn belief blog prothero'],
#  [69, 'fyi'],
#  [70, 'octob hillari'],
#  [71, 'pi print'],
#  [72,
#   'pouch call sheet schedul en rout well also pouch read item action memo author war power resolut tunisia offic would like approv today op send courier pick action memo later today uk fm hagu egyptian fm amr isra pm netanyahu french fm fabiu saudi fm saud somali former transit presid sherif libyan turkish fm davutoglu somali presid mohamoud moroccan king still pend new call king juan carlo spain call today offer anytim today tomorrow hi offic relay person call inquir statu embassi middl east work call sheet'],
#  [73,
#   'prom nora toiv mato sent sun ay april pm mill ateryl subject exclus bill clinton say would rule arm uhya rebel exclus bill clinton say would rule arm libya rebel pm speak former presid say suzan claric april former presid bill clinton said think unit state consid arm rebel civil war would depend might need know littl would inclin clinton told correspond bianna golodryga today san diego dure exclus interview abc news clinton wa san diego hi annual clinton global initi univers meet upris libya stare februari dure wave social polit unrest middl east fight ha escal across countri rebel found themselv outgun libyan leader moamrnar gadhafi forc better equip last month unit nation author zone north african nation prevent attack civilian gadhafiss troop air clinton arm rebel sure would shut door unit state back zone ha also author addit support hafi fighter key lawmak top offici govern presid barack obanaa said comfort arm rebel appar becaus enough known clinton said would complet rule idea suppli arm libya rebel depart state case doc date state dept produc hous select benghazi comm subject agreement sensit inform redact foia waiver depart state case doc date state dept produc hous select benghazi comm subject agreement sensit inform redact foia waiver let say thi sure would shut door think may need know littl said clinton husband secretari state hillari clinton stress wa speak without ani offici sanction whatsoev speak certainli would take tabl said watch interview bill clinton monday morn gadhafi focu investig intern crimin court hagu watch good morn america full interview hear clinton speak hi summit loom govern shutdown controversi presid obama birth certif copyright abc news internet ventur depart state case doc date state dept produc hous select benghazi comm subject agreement sensit inform redact foia waiver'],
#  [74, 'use insight pl circul'],
#  [75, 'j'],
#  [76,
#   'fyi discuss fulli agre nato liaison good idea prom feibran jeffrey sent friday april pm daaider ivo h gene polaschlk joan gordon philip h roebuck william v keen matt e dibbl elizabeth l cc sullivan jacob schikher ronald l sanderson janet djerassi alexand heffern john degnan kelli c subject itenghazi nato ivo thank help respons nea perspect oper liaison tnc doe constitut formal legal recognit inc govern libya consid chri steven presenc benghazi trigger formal recognit never broken relat libya despit suspend embassi oper without question nato liaison benghazi would appear nato lean direct inc nato oper alreadi show consider lean away qadhati speak nea mind appear real purpos would avoid friendli fire incid cours cheer jeff jeffrey fettman assist secretari bureau near eastern affair depart state'],
#  [77, 'postelect like dinner bill come town whatev work'],
#  [78,
#   'sullivan jacob j sullivanjj sunday octob pm h great see drop libya sid'],
#  [79, 'thank princ saud'],
#  [80, ''],
#  [81,
#   'friday april pm h uk game play new rebel strategist egypt move sid hre memo uk game new rebel strategist egypt move hrc memo uk game new rebel strategist egypt move hillari'],
#  [82,
#   'hillari want offer person condol loss four fine foreign servic offic ambassador wa perfect role model kind person need repres us around world much give alreadi given much know ha hard week want simpli express sympathi tell wa think bob gate depart state case doc date state dept produc hous select benghazi comm subject agreement sensit inform redact foia waiver'],
#  [83, 'call'],
#  [84, ''],
#  [85, ''],
#  [86,
#   'h friday april pm fvv h uk game play new rebel strategist egypt move sid hit memo uk game new rebel strategist egypt move fyi'],
#  [87,
#   'madam secretari latest draft friday speech long minut thi version comfort gener direct streamlin thank dan depart state case doc date state dept produc hous select benghazi comm subject agreement sensit inform redact foia waiver depart state case doc date state dept produc hous select benghazi comm subject agreement sensit inform redact foia waiver secretari state hillari rodham clinton remark maghreb transit center strateg intern studi washington dc ocmber depart state case doc date state dept produc hous select benghazi comm subject agreement sensit inform redact foia waiver depart state case doc date state dept produc hous select benghazi comm subject agreement sensit inform redact foia waiver depart state case doc date state dept produc hous select benghazi comm subject agreement sensit inform redact foia waiver depart state case doc date state dept produc hous select benghazi comm subject agreement sensit inform redact foia waiver depart state case doc date state dept produc hous select benghazi comm subject agreement sensit inform redact foia waiver depart state case doc date state dept produc hous select benghazi comm subject agreement sensit inform redact foia waiver depart state case doc date state dept produc hous select benghazi comm subject agreement sensit inform redact foia waiver depart state case doc date state dept produc hous select benghazi comm subject agreement sensit inform redact foia waiver depart state case doc date state dept produc hous select benghazi comm subject agreement sensit inform redact foia waiver depart state case doc date state dept produc hous select benghazi comm subject agreement sensit inform redact foia waiver depart state case doc date state dept produc hous select benghazi comm subject agreement sensit inform redact foia waiver depart state case doc date state dept produc hous select benghazi comm subject agreement sensit inform redact foia waiver depart state case doc date state dept produc hous select benghazi comm subject agreement sensit inform redact foia waiver depart state case doc date state dept produc hous select benghazi comm subject agreement sensit inform redact foia waiver depart state case doc date state dept produc hous select benghazi comm subject agreement sensit inform redact foia waiver depart state case doc date state dept produc hous select benghazi comm subject agreement sensit inform redact foia waiver depart state case doc date state dept produc hous select benghazi comm subject agreement sensit inform redact foia waiver depart state case doc date state dept produc hous select benghazi comm subject agreement sensit inform redact foia waiver depart state case doc date state dept produc hous select benghazi comm subject agreement sensit inform redact foia waiver depart state case doc date state dept produc hous select benghazi comm subject agreement sensit inform redact foia waiver depart state case doc date state dept produc hous select benghazi comm subject agreement sensit inform redact foia waiver depart state case doc date state dept produc hous select benghazi comm subject agreement sensit inform redact foia waiver depart state case doc date state dept produc hous select benghazi comm subject agreement sensit inform redact foia waiver'],
#  [88,
#   'approv war power act action memo king morocco ha gotten back us time op tri reason hour moroccan attorney gener holder ha request speak regard depart justic libya investig stand would like take thi tonight depart state case doc date state dept produc hous select benghazi comm subject agreement sensit inform redact foia waiver'],
#  [89, 'hrc csi sorri coupl hour late'],
#  [90,
#   'approv pick call w king schedul keep work w huma speak holder doe need speak secur either'],
#  [91, 'send print copi book tonight shortli'],
#  [92, 'import high jake may sent case'],
#  [93, 'ye ii give memo servic downstair holder king'],
#  [94, 'surviv ye pat help level set thing tonight see morn'],
#  [95, ''],
#  [96, ''],
#  [97,
#   'thank offer holder wait hear would like speak secur like wo hear king sever hour keep post soon'],
#  [98,
#   'tom move yellow chair close went knee knee amaz tri knee knee wa enough lean forward like pivot far torso could fold forward minim space head wa like dental hygienist roll around floor get best access mouth depend tooth wa tri get access never seen western invad space like even non western seen base cultur differ onli briefli greet thi went like minut unaccept ani cultur even think see behavior among ani type mammal touch leg repeatedli call wa gravi wa wonder one best interview ever wit wish live tv'],
#  [99, 'speak said doe secur op connect resid'],
#  [100, ''],
#  [101,
#   'depart state case doc date state dept produc hous select benghazi comm subject agreement sensit inform redact foia waiver'],
#  [102, 'donna'],
#  [103, 'one flag tighten trim send updat draft offic first thing morn dan'],
#  [104, 'thx also dc'],
#  [105, ''],
#  [106, 'ok read whole thing email'],
#  [107, 'go'],
#  [108,
#   'firm fogarti daniel sent tuesday april mill cheryl stilin jacob abedin hume web ake g cc subject steven updat benghazi op ha provid latest steven updat benghazi traffkaccidenti polic accept usg version stori wa accid victim wear seathelt usg employe return airport incid occur total four peopl die six injur usg employe mjuri light ani peopl stand pend offici usg instruct steven note uk flight tomorrow could necessari tnc want press releas quell rumor mill steven send draft back depart l pa clearanc british envoy depart tomorrow perman chang station gap befor hi replac john jenkin arriv baghdad inc head malunoud fibril go jordan back benghazi friday develop like met addit critic spend much time abroad expens govern affair thank dan depart state case doc date state dept produc hous select benghazi comm subject agreement sensit inform redact foia waiver'],
#  [109, 'new version altern end edit dan'],
#  [110, 'sorri actual florida weekend'],
#  [111, 'detail overnight traffic accid'],
#  [112, ''],
#  [113, 'dan come'],
#  [114,
#   'monday may h ubl aq libya sid hrc memo bin laden aq hrc memo bin laden aq may hillari'],
#  [115, 'hi offic call said avail want take thi morn'],
#  [116, 'right'],
#  [117, ''],
#  [118, 'right'],
#  [119,
#   'h monday may fw h ubl aq libya sid hrc memo bin laden aq pi print sent monday may h subject h ubl aq libya sid may hillari'],
#  [120, 'fyi'],
#  [121, 'op build call call sheet email'],
#  [122,
#   'h friday may fw h ubl aq libya sid hrc memo bin laden aq pass disturb true sent monday may h subject h ubl aq libya sid may hillari'],
#  [123,
#   'want tell speech yesterday wa terrif import say never perfect secur diplomat ca oper bunker world danger place thought nyt articl thi morn help well understand defens love offens thank ani us help reinforc let us know depart state case doc date state dept produc hous select benghazi comm subject agreement sensit inform redact foia waiver'],
#  [124, 'inal messag'],
#  [125,
#   'releas part strike littl strang certainli disturb pass info prom h mailto sent friday may sullivan jacob subject fw h usl aq libya sid pass disturb true sent monday may h subject h ubl aq libya sid may hillari'],
#  [126, ''],
#  [127,
#   'susan thi week wa ask whether ani intel make clear view thi start spontan evolv onli troubl sentenc relat investig specif see investig unfold whether wa transpir benghazi might unfold differ differ circumst got push wait transcript happen whi let bring ambassador unit nation susan rice rice thank join us rice good jake tapper first latest tell us attack embassi consul benghazi hear libyan arrest peopl say peopl involv outsid countri might even al qaida tie latest inform rice well jake first import know fbi investig ha begun take time complet tell us certainti transpir current best assess base inform present fact thi began wa spontan premedit respons transpir cairo cairo know hour earlier wa violent protest wa undertaken reaction thi veri offens video wa dissemin believ folk benghazi small number peopl came embassi consul rather replic sort challeng wa pose cairo unfold seem hijack let us say individu cluster extremist came heavier weapon weapon know wake revolut libya quit common access evolv depart state case doc date state dept produc hous select benghazi comm subject agreement sensit inform redact foia waiver depart state case doc date state dept produc hous select benghazi comm subject agreement sensit inform redact foia waiver wait see exactli investig final confirm best inform present tapper whi wa secur breakdown whi wa better secur compound benghazi whi marin embassi tripoli rice well first substanti secur presenc personnel tapper substanti enough though right rice personnel consul benghazi tragic two four american kill provid secur wa function inde mani colleagu obvious prove suffici natur attack suffici moment whi obvious reinforc remain presenc tripoli whi presid ha veri veri clear libya throughout region go call govern first assum respons protect facil personnel reinforc facil embassi possibl tapper whi rice need tapper whi would marin embassi tripoli begin would seem like thi thi obvious unstabl countri thi region interest attack previou month whi marin begin rice first marin place around world marin everi facil depend circumst depend requir presenc tripoli benghazi rel new recal back onli matter month visit tripoli benghazi wa veri grate strong secur presenc part embassi detach certainli awar libya place increasingli violent incid secur personnel state depart thought requir place see investig unfold whether wa transpir benghazi might unfold differ differ circumst presid ha veri clear protect american personnel facil remain top prioriti whi reinforc presenc tripoli elsewher depart state case doc date state dept produc hous select benghazi comm subject agreement sensit inform redact foia waiver depart state case doc date state dept produc hous select benghazi comm subject agreement sensit inform redact foia waiver tapper look thi map would protest around world last sever day presid obama pledg repair america relationship muslim world whi doe seem impot whi even less popular today muslim arab countri wa four year ago rice jake impot even less popular challeng assess know basi make judgment let let point tapper seem govern powerless thi thi maelstrom erupt rice actual opposit first let clear transpir happen thi week cairo benghazi mani part region tapper tunisia khartoum rice wa result direct result heinou offens video wa wide dissemin govern noth made clear reprehens disgust also veri clear say excus violenc condemn strongest possibl term let look happen quit opposit impot work govern egypt presid obama pick phone talk presid morsi egypt soon secur provid personnel embassi dramat increas presid morsi tapper took two day presid morsi say anyth thi rice presid morsi ha repeatedli said condemn thi violenc call hi peopl call ani demonstr made veri clear thi ha stop crosstalk rice frankli tunisia yemen cours libya govern ha ha gone way tri step secur express deepest remors ha happen quit popular libya might expect major partner revolut transpir outsid consul benghazi wa express part libyan peopl quit contrari outpour  ...
#  [128, 'june hillari'],
#  [129, ''],
#  [130, 'plan'],
#  [131,
#   'friday june pm h memo attach q secret bid uk sid hrc memo q secret bid uk hrc memo q secret bid uk depart case doc date state dept produc hous select benghazi comm subject agreement sensit inform redact foia waiver depart state case doc date state dept produc hous select benghazi comm subject agreement sensit inform redact foia waiver june hillari'],
#  [132, 'veri nice talk'],
#  [133, 'car drive bit'],
#  [134,
#   'h clintonemailcorn friday june pm fw h new memo qs secret bid uk sid jake fyi print'],
#  [135, 'good'],
#  [136, 'noth thi one'],
#  [137, 'home ny call'],
#  [138, ''],
#  [139, 'interest'],
#  [140, ''],
#  [141,
#   'credibl threat info hotel team use rest intl commun use matter ds go evacu peopl alt locat info suggest attack next hour keep post depart state case doc date state dept produc hous select benghazi comm subject agreement sensit inform redact foia waiver'],
#  [142,
#   'monday august pm h kill youni whi sid hrc memo kill youni hrc memo kill youni august hillari'],
#  [143,
#   'sullivan jacob j sullivanjj sunday septemb pm press transcript ambassador unit nation susan rice'],
#  [144,
#   'h monday octob pm fw fwd salon death ambassador chri steven need expeditionari diplomaci real lesson diplomaci pl print'],
#  [145, ''],
#  [146, ''],
#  [147,
# ...
#  [767, 'h tuesday septemb huma abedin fw sheikha mosa qatar lona work thi'],
#  [768, 'one reaction want derek handl india dialogu'],
#  [769, 'pl give print copi today'],
#  [770, 'pi add call list discuss iraq elect monitor karla rubing'],
#  [771, 'pi print'],
#  [772,
#   'h tuesday septemb congrat jacki swear ceremoni max still rise best seller list'],
#  [773, 'would love see randi copi lona see soon schedul hope well'],
#  [774, 'cook stove export control visa reform categori vet'],
#  [775, 'judith hope'],
#  [776, 'make sens go ahead thx'],
#  [777, 'pl tri set week unga'],
#  [778, 'pl print mtg'],
#  [779, 'also give copi eap rep mtg'],
#  [780, 'lunch'],
#  [781, 'help guid get someth good eat'],
#  [782, 'dan redraft'],
#  [783, 'could leav earlier sat btw sinc mtg fri night'],
#  [784, 'thank help work schedul time look forward see ny next week'],
#  [785, 'see kristi hand thi tonight tomorrow'],
#  [786, 'leav late friday wh mtg'],
#  [787,
#   'understand suppos talk turkish fm polish fm found kerri lugar berman btw call mubarak king abdullah know ani call'],
#  [788,
#   'need see merncon followup cover mani subject time respond need talk w thi weekend'],
#  [789, 'henriett kolb releas part'],
#  [790, 'know thi wish discuss'],
#  [791, 'time plane tomorrow night'],
#  [792, 'ok'],
#  [793, ''],
#  [794,
#   'pl tell lona huma return state fsi also could jim meet room w buffet floor lunch'],
#  [795, 'also mention'],
#  [796, ''],
#  [797, 'ye'],
#  [798, 'also email copi speech yesterday oscar print'],
#  [799, ''],
#  [800, 'date yet thought appar confirm w qatari pl let know respond cheri'],
#  [801, 'h sunday septemb millscd talk releas part know see deni call'],
#  [802,
#   'pl let know follow kabila may luncheon thi week least could say someth deliv letter'],
#  [803, 'hope bilater meet across tabl chair happen'],
#  [804, 'receiv thi fall buy person use'],
#  [805, 'sure know happi pay state talk w justin'],
#  [806, 'ok'],
#  [807, 'would love see play time ear copi huma lona help schedul'],
#  [808,
#   'would good idea pass copi nytim magazin issu half sky w interview sever event women issu'],
#  [809,
#   'unga question time potu meet w israel pa go deforest mtg todd go know yet summit potu singapor like set mtg w john kerri week unga offer choic want come state make clear come meet hi offic place hi choos also w durbin mtg owe one sure wait larger mtg dec mtg costa rico may want attend part larger latin trip'],
#  [810, 'need find time meet w undersectretari everi week suggest'],
#  [811,
#   'matter rais w want get reaction wa ani followup offer afghan women memo prioriti fy announc global women fund partnership unga close coordin w wh council strengthen aid women offic congress member ok w work prioriti far budget un women voic insid outsid mark anniv cairo let thorough review cedaw strategi ask contract w h lead effort followup w doug hattaway work w alec ross eca work w wha julissa reynoso econ issu w mepi staf see kay warren wa dc eric goosbi swear'],
#  [812, 'mtg'],
#  [813, 'ok go'],
#  [814,
#   'cheri thi strang sinc meet wa confirm sever day ago fact offic call back say wa onli time work confirm know thi thx'],
#  [815, 'thi doe sound like anyth pl keep inform'],
#  [816, 'could tuesday'],
#  [817, 'ye first sure ds come time'],
#  [818, 'proud compani keep thx chanc speak brook best h'],
#  [819, 'h sunday septemb pm cgi speech first draft ny thx'],
#  [820,
#   'h sunday septemb pm could talk endless call un could call earli tomorrow would btw earli pleas wear sock bed keep feet warm'],
#  [821,
#   'h sunday septemb pm eid mubarak releas part great thx much hope see well'],
#  [822, 'mike plan work w epa thi may come mtg climat chang thi week hrc'],
#  [823, 'h monday septemb pm state next'],
#  [824, 'would write letter could deliv set thi'],
#  [825, 'need talk'],
#  [826,
#   'kri follow issu let know report back thx steve schwarzman blackston want help visa said mickey kantor wa talk cheryl statu ina david cote honeywel want help w also complain export control reg interfer w sale said state dept holdup gave exampl nut bolt engin label dual use therefor could export andrew may know thi'],
#  [827, 'glad'],
#  [828, 'ok'],
#  [829, 'steinberg need upfront earli'],
#  [830,
#   'confus urg reschedul whatev els ha come also tell nsc thi retreat dc pc wh mtg day'],
#  [831, 'put agenda befor jack overview issu topic'],
#  [832, 'upstair mtg meet room'],
#  [833, 'come morn mtg w'],
#  [834, 'work idea cgi speech'],
#  [835, 'pi print review cgi speech'],
#  [836,
#   'h thursday se tember sullivanjj fw un overlook sourc idea topper time event make case probabl right'],
#  [837, 'capricia hotel love see let know thx team h'],
#  [838, 'found cours tri herd cat see back dc'],
#  [839,
#   'tri organ note need list date time mtg event unfortun card take note date time usual would like alway includ send'],
#  [840, 'thank much'],
#  [841, 'ask chines let us take helicopt retriev'],
#  [842, 'reason ask post news peopl quot say ask help sinc technic china'],
#  [843, 'suppos'],
#  [844,
#   'read cm philadelphia back least like call time howev hard visit sinc need see santa around see lisa might work want see peopl close friend think'],
#  [845, 'heard david broder good column today see pi send wa face nation'],
#  [846, 'saw broder piec write part'],
#  [847, 'ok meet waldorf'],
#  [848, 'made progress'],
#  [849, 'cheryl postpon get bill'],
#  [850,
#   'first wa told wa come assum second use free time go stuff friday need long mtg w holbrook team sometim day time work home want talk'],
#  [851,
#   'holbrook want long hour mtg want friday pl confirm w time op center want eikenberri paterson video let get thi nail plan rest day'],
#  [852, 'ok'],
#  [853,
#   'h tuesday septemb herieblair huma abedin sorri miss realli enjoy time w friend hope work togeth issu includ project peopl w disabl copi huma wa w follow sorri see onli minut w toni quartet mtg may london later thi month let know happen best'],
#  [854,
#   'terri often littl control schedul day look close thi let know copi lona followup best'],
#  [855, 'pl print'],
#  [856, 'pl print'],
#  [857, ''],
#  [858, 'want ask check w eikenberri memo request wa onli send'],
#  [859, ''],
#  [860, 'h tuesday septemb pm fw vet thi request advis thx'],
#  [861, 'would like see holbrook befor go airport get come'],
#  [862, 'worri saw'],
#  [863,
#   'fyi info deal mention yesterday young woman speak mandarin focus china energi militari develop'],
#  [864, 'releas part'],
#  [865, 'hi email white hous'],
#  [866,
#   'pi find whether support surg iraq get copi hi recent speech troop af thx'],
#  [867,
#   'demint go encourag go time present balanc pictur defacto demint use mil air add member'],
#  [868, 'ok'],
#  [869,
#   'shuttl goe well stop first state base work w suggest point make set us counterpart militari prepar friday next week'],
#  [870,
#   'see kori schake articl wsjournal fri attack civilian effort af answer convincingli point karl request'],
#  [871, 'total usg spent af sinc believ spent pak'],
#  [872, 'pi sure see joe'],
#  [873,
#   'happen hrc geneva need call anyon pere ask person call feel need updat phone w harold'],
#  [874, 'later'],
#  [875, 'secretari soon call tell op set'],
#  [876,
#   'want see propos statement happi issu someon els name think need weigh thx'],
#  [877, 'like idea issu someon els still want see let close thi'],
#  [878,
#   'h saturday octob pm statement happi melann send letter gosl ambassador mayb un rep onli releas sl relat outlet'],
#  [879, 'send funer deleg'],
#  [880, 'give background thi mtg becaus lula want talk wpotu'],
#  [881, 'pl print three copi thi'],
#  [882, 'h saturday octob pm statement'],
#  [883, 'pl read respond thi veri concern'],
#  [884, 'thx'],
#  [885, 'delight recharg pi take whatev time fish posit thought'],
#  [886,
#   'want take pm shuttl want meet w jake holbrook team either state hous whichev prefer'],
#  [887, ''],
#  [888, 'sure got home'],
#  [889, 'ye'],
#  [890, 'ok doe eikenberri need secur'],
#  [891, 'set also call chri hill call op directli guy'],
#  [892,
#   'melann sent email burn forward kay warren lynn lusi email express concern partnership w norway announc want anyth undermin heal africa send train let know answer anxieti sinc admir h'],
#  [893, 'given afp stori today deliv letter given appropri press includ afp'],
#  [894,
#   'need detail embassi thi deal russian often overpromis regardless prove whi need go'],
#  [895, 'come help w test'],
#  [896, ''],
#  [897,
#   'releas part pilot plane owner insist leav last night becaus hurrican anyway home call later catch feel free call need'],
#  [898, 'let get call set right befor fax'],
#  [899,
#   'see photo nypost bill yesterday wa lunch see anybodi w camera obvious long len afar'],
#  [900, 'noth come'],
#  [901, 'ok'],
#  [902,
#   'realli want go cronkit servic chang time mcc late afternoon jack presid'],
#  [903, 'came home earli becaus hurrican know box arriv today'],
#  [904, 'schedul call today monday'],
#  [905,
#   'romulo said welcom addit help told pl follow w ambassador think follow well veri bad line wirajuda seem welcom support includ helicopt navel asset pl followup navi well let know els need'],
#  [906, 'thx h sunday octob sri lanka'],
#  [907, 'fax hous email huma print'],
#  [908, 'suppos see get back'],
#  [909, 'ok w'],
#  [910,
#   'think quit good cover issu well think need addit lead discuss holbrook want talk ani feedback befot call'],
#  [911, 'bunch best way process conf call w whoever need includ'],
#  [912, 'take shuttl next half hour anyth need know befor call richard back'],
#  [913, 'fax dc hous talk thru w'],
#  [914, 'h sunday octob pm thank sandi thi veri help'],
#  [915,
#   'melann thank say hello everyon also pl send info fff copi megan rooney jake work speech forum take care'],
#  [916, 'find thi latest memo draft confus way laid pl call'],
#  [917,
#   'assist foundat megan jake pl see info melann gender issu forum like includ refer work way forward speech tomorrow thx'],
#  [918, ''],
#  [919, ''],
#  [920, ''],
#  [921, ''],
#  [922, 'sorri come abl knock door bedroom close also talk w cheryl'],
#  [923,
#   'scott think thi idea worth explor ask cheryl work w run trap discuss w anyon wh yet like know reaction thank dedic work hrc'],
#  [924, 'doe email address'],
#  [925,
#   'doug pakistan govern sure use help like talk w judith mchale work w holbrook team includ ashley copi judith paul jone amb holbrook deputi coordin followup pl let know next step w amb haqqani thank work global women issu best h'],
#  [926,
#   'dear nanci veri much want meet tri pin schedul enough offer date onli time see befor decemb nov sometim second third week decemb copi cheryl two tri find time work name think worth invit w hope come let best h'],
#  [927, 'pl add mort zuckerman ed town'],
#  [928, 'thx'],
#  [929, 'ye befor btw btw'],
#  [930,
#   'strobe thi wonder news fit memori book also would like talk w idea could call next day time best h'],
#  [931, 'would like talk thi rch stuff'],
#  [932, 'suppos call'],
#  [933, 'could women fm head state dinner instead lunch'],
#  [934,
#   'h saturday august pm brook memori fellowship india strobe congratul call tomorrow morn around call h'],
#  [935,
#   'mari landrieu ask attend dinner foster care ani detail also mention event white hous adopt foster care heard anyth thi call landrieu offic follow told kouchner would call pl remind'],
#  [936, 'like readout call also idea'],
#  [937, 'pl apolog necessari'],
#  [938, 'hi email'],
#  [939, 'told andrew would thing request hi memo talk schedul'],
#  [940,
#   'h monday novemb jim phil return hi call discuss macedonia name issu cypru relat w turkey memcon reflect hi state commit solv improv statu issu known long time happi follow w ani matter w guidanc seem determin put point board fast start intensifi effort w let know els want thx'],
#  [941, 'hi email c'],
#  [942, 'wa unga foreign leader facebook would like see find'],
#  [943,
#   'tom craig spoke w secretari soli thank go hondura eager brief advic meet w today veri import craig go w guid thru thi process oscar aria told veri worri whether agreement implement meet w lead presidenti candid thi week urg produc hi parti vote restitut also spoke w insulza focuss elect told would fulli support thank great work good luck effort get thi across finish line best hrc'],
#  [944, 'fyi'],
#  [945, 'come see discuss thx'],
#  [946, 'bartholomew marshal capricia p verveer melann releas part'],
#  [947, 'let jack offic'],
#  [948, 'dc thi week'],
#  [949, 'thx tomorrow want go hous pick someth send overnight'],
#  [950,
#   'h tuesday novemb morocco ambassador jaidi send hi warmest wish let discuss soon countri time also much review forum cairo befor come dc tomorrow night'],
#  [951, ''],
#  [952, 'jack two pc go somalia aid'],
#  [953, 'love idea gladli whatev decid'],
#  [954, 'get site like mtvu would great'],
#  [955, 'richard wa reaction pc yesterday next process hope recov trip h'],
#  [956, ''],
#  [957, 'call'],
#  [958, 'pi print'],
#  [959,
#   'clinton reflect amaz strength purpos keep si love could sure get thi articl'],
#  [960,
#   'h wednesday octob rose thx pass feedback share w let plan anoth catch call copi assist lauren tri schedul us'],
#  [961,
#   'clinton reflect amaz strength purpos keep si love releas part fax broken get ani clip hope get fix today hope receiv miss'],
#  [962,
#   'lisa land cairo would love come lunch dc let know time place copi lona connect w sinc leav sat two week thi travel gig never end ca wait thanksgiv day hope well friend'],
#  [963,
#   'thi decis issu us germani also heard rumor phil murphi wa call merkel thi true see tomorrow discuss thx l'],
#  [964, 'ns print h thursday novemb fw fyi declin fall british empir edit sid'],
#  [965, 'pi print'],
#  [966, ''],
#  [967, ''],
#  [968,
#   'h thursday novemb ed luce articl great articl thx copi pj philipp see us press coverag us effort'],
#  [969, 'doe articl compar cover huma abe'],
#  [970, 'pi print h thursday octob fw troop'],
#  [971, ''],
#  [972,
#   'articl campaihn spend compar spend total juli thru nov mislead sinc less five month campaign get correct somewher'],
#  [973, 'thi'],
#  [974, 'come back'],
#  [975, 'celebr'],
#  [976, 'pl print'],
#  [977, 'potu run late kati tell us come back befor'],
#  [978, 'pi print h thursday octob pm fw whi powder coat'],
#  [979, 'pi print'],
#  [980, ''],
#  [981, 'call ifyou'],
#  [982, 'hope achiev power poetri short monday remark'],
#  [983, 'still call'],
#  [984, 'pl print h friday novemb fw also may never mention'],
#  [985, 'consult sid absolut pi thank send address'],
#  [986, 'releas part pl print'],
#  [987, 'consult sid lauren'],
#  [988, 'pl print'],
#  [989,
#   'lisa land cairo would love come lunch dc let know time place copi lona connect w sinc leav sat two week thi travel gig never end ca wait thanksgiv day hope well friend'],
#  [990, 'pl print attach'],
#  [991, 'agre whi leav'],
#  [992, 'tri befor success want explor'],
#  [993,
#   'h saturday octob fw would like someth bill think could good followup dialogu think'],
#  [994, 'sound good'],
#  [995, 'samoa great job'],
#  [996, 'pl print'],
#  [997, ''],
#  [998, ''],
#  [999,
#   'h saturday octob pm check see ani messag heard news gordon eye doe mean'],
#  [1000, 'thx spoke w georg plane befor land oin dublin agre safe travel'],
#  ...]

# %% [markdown]
# Function to iterate over the text to extract our lemmas

# %%
def tokenize_lemmatize_text(text):
    lemmas = []  # Create a local list to store tokens for each text
    tokens = word_tokenize(text)
    for token in tokens:
        if token in stop_words:
            continue
        else:
            lemmas.append(stemmer.stem(token))
    return lemmas

# %% [markdown]
# Testing on one email for clarity.

# %%
# Assuming 'corpus' is your list of emails and 'tokenize_lemmatize_text' is the modified function

# Retrieve the content of the third email
third_email_content = corpus[2][1]  # Index 2 corresponds to the third element (0-based index)

# Call the function to get lemmas for the third email
third_email_lemmas = tokenize_lemmatize_text(third_email_content)

# Print the lemmas
print(third_email_lemmas)
# Out:
# ['thx']

# %%
# Initialize a defaultdict to store bigram counts
bigram_freqs = {}

# Iterate over each email in the corpus
for _, email_content in corpus:
    # Tokenize and lemmatize the email content
    email_token_lemmas = tokenize_lemmatize_text(email_content)

    # Create a list of bigrams
    email_bigrams = [(email_token_lemmas[i], email_token_lemmas[i + 1]) for i in range(len(email_token_lemmas) - 1)]

    # Update the bigram frequencies
    for bigram in email_bigrams:
        bigram_freqs[bigram] = bigram_freqs.get(bigram, 0) + 1

# Create a DataFrame from the bigram frequencies
df = pd.DataFrame(list(bigram_freqs.items()), columns=['bigram', 'freq'])

# Sort the DataFrame by frequency in descending order
df = df.sort_values(by='freq', ascending=False)

# Expand bigrams into separate columns
df[['first_term', 'second_term']] = pd.DataFrame(df['bigram'].tolist(), index=df.index)

# %% [markdown]
# The top 50 most frequently appearing bigrams provide useful combinations. There may be a method to include these in the lemmatizer.

# %%
df.head(50)
# Out:
#                      bigram  freq first_term second_term
# 1771     (secretari, offic)   461  secretari       offic
# 1764        (state, depart)   457      state      depart
# 122           (unit, state)   447       unit       state
# 1846           (white, hou)   416      white         hou
# 50          (depart, state)   400     depart       state
# 1762             (en, rout)   314         en        rout
# 6389        (pm, secretari)   279         pm   secretari
# 6401            (offic, pm)   263      offic          pm
# 888      (secretari, state)   258  secretari       state
# 2                   (pm, h)   229         pm           h
# 55            (state, dept)   226      state        dept
# 2207            (new, york)   224        new        york
# 53              (doc, date)   224        doc        date
# 1760        (privat, resid)   218     privat       resid
# 59       (select, benghazi)   216     select    benghazi
# 57            (produc, hou)   216     produc         hou
# 58            (hou, select)   216        hou      select
# 56           (dept, produc)   216       dept      produc
# 67           (foia, waiver)   216       foia      waiver
# 60         (benghazi, comm)   216   benghazi        comm
# 62     (subject, agreement)   216    subject   agreement
# 64         (sensit, inform)   216     sensit      inform
# 65         (inform, redact)   216     inform      redact
# 66           (redact, foia)   216     redact        foia
# 63      (agreement, sensit)   216  agreement      sensit
# 52              (case, doc)   215       case         doc
# 51            (state, case)   213      state        case
# 80           (mill, cheryl)   212       mill      cheryl
# 61          (comm, subject)   212       comm     subject
# 54            (date, state)   211       date       state
# 1862            (pm, arriv)   208         pm       arriv
# 1855           (pm, depart)   208         pm      depart
# 17049        (health, care)   167     health        care
# 2469            (let, know)   167        let        know
# 856         (prime, minist)   167      prime      minist
# 1778         (confer, room)   161     confer        room
# 7509         (abedin, huma)   158     abedin        huma
# 2015      (foreign, polici)   154    foreign      polici
# 1881          (offic, time)   149      offic        time
# 5922      (foreign, minist)   147    foreign      minist
# 104         (presid, obama)   146     presid       obama
# 692       (sullivan, jacob)   144   sullivan       jacob
# 421           (middl, east)   142      middl        east
# 137         (nation, secur)   142     nation       secur
# 6464      (cheryl, millscd)   140     cheryl     millscd
# 1777    (secretari, confer)   137  secretari      confer
# 190          (human, right)   130      human       right
# 13853          (tea, parti)   128        tea       parti
# 3028          (relea, part)   127      relea        part
# 693              (jacob, j)   127      jacob           j

# %% [markdown]
# **(2) Exploratory Data Analysis**

# %%
emails.shape
# Out:
# (7945, 21)

# %%
emails.columns
# Out:
# Index(['Id', 'DocNumber', 'MetadataSubject', 'MetadataTo', 'MetadataFrom',
#        'SenderPersonId', 'MetadataDateSent', 'MetadataDateReleased',
#        'MetadataPdfLink', 'MetadataCaseNumber', 'MetadataDocumentClass',
#        'ExtractedSubject', 'ExtractedTo', 'ExtractedFrom', 'ExtractedCc',
#        'ExtractedCaseNumber', 'ExtractedDocNumber', 'ExtractedDateReleased',
#        'ExtractedReleaseInPartOrFull', 'ExtractedBodyText', 'RawText'],
#       dtype='object')

# %% [markdown]
# Analyzing the distribution of emails over time
#
# - Hillary Clinton served as a secretary of state from 2009-2013.
# - We observe that from 2009-2011, there are a significant amount of emails, but there are sudden drop in January of 2011.
# - Since there were more than 300 emails per 6 months between July 2009 and January 2011, it does not make sense that January 2011 to July of 2012, there are less than total of 100 emails. Because of the nature of this dataset, we can suspect that the dataset does not include much information about emails from this time period or we can assume she used different email to communicate.

# %%
unfiltered_emails = pd.read_csv("Emails.csv")

# Convert 'ExtractedDateSent' to datetime format
unfiltered_emails['ExtractedDateSent'] = pd.to_datetime(unfiltered_emails['ExtractedDateSent'], errors='coerce')

# Drop rows where 'ExtractedDateSent' is missing or not a valid date
unfiltered_emails = unfiltered_emails.dropna(subset=['ExtractedDateSent'])

# Plot the distribution of emails over time
plt.figure(figsize=(12, 6))
plt.hist(unfiltered_emails['ExtractedDateSent'], bins=50, color='skyblue')
plt.xlabel('Date')
plt.ylabel('Number of Emails')
plt.title('Distribution of Emails Over Time')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# Most frequent senders and recipients:

# %% [markdown]
# Top 10 Senders of Emails
#
# - Hillary Clinton sent most emails, which is obvious considering this information is from Clinton's email. Huma Abedin, who was vice chair of Clinton's 2016 campaign, was the second primary senders of emails. Cheryl Mills served as a counselor and chief of staff for Clinton. Jake Sullivan was a senior policy a"dvisor for Clinton's 2016 presidential campaign and also served with Clinton as a national security advisor and aid in the State Department during the Obama administration. These three are the most significant senders of emails.
# - From these top senders of emails, we can see that the ones who communicated the most with Clinton are those who worked very closely with Clinton. Others have experience working with Clinton as well but seeing from the sudden decrease in number of emails sent, we suspect that Clinton worked most closely with Abedin, Mills, and Sullivan.
# - It would be interesting to see the top subjects in each sender's email. We could use tf-idf to further investigate upon this.

# %%
unf_emails = pd.read_csv("Emails.csv")
persons = pd.read_csv("Persons.csv")

# Get the count of emails sent by each sender
senders_counts = unf_emails['SenderPersonId'].value_counts().reset_index()
senders_counts.columns = ['SenderPersonId', 'EmailsSent']

# Merge with Persons.csv to get sender names
senders_counts = senders_counts.merge(persons, left_on='SenderPersonId', right_on='Id', how='left')

# Sort the data by the total count
senders_counts = senders_counts.sort_values(by='EmailsSent', ascending=False)

# Get the top 10 senders
top_senders = senders_counts.head(10)

plt.figure(figsize=(12, 6))
plt.bar(top_senders['Name'], top_senders['EmailsSent'])
plt.xlabel('Sender')
plt.ylabel('Number of Emails Sent')
plt.title('Top 10 Senders of Emails')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# Top 10 Receivers of Email
#
# - Similar to Top 10 senders of emails, Hillary received the most emails, which can be understood by the nature of this dataset. There is significant overlap between top senders and top receivers.
# - Because the dataset did not contain Receiver ID, this graph contains duplicates. abedinh@state.gov and Abedin, Huma are the same people, as well as H and Hillary.
# - There could be more data cleaning and merging the received number of emails together by using the name column of Aliases.csv.

# %%
unf_emails = pd.read_csv("Emails.csv")

# Get the count of emails received by each receiver
receivers_counts = unf_emails.groupby('MetadataTo').size().reset_index(name='EmailsReceived')

# Fill missing values with 0
receivers_counts = receivers_counts.fillna(0)

# Sort the data by the total count
receivers_counts = receivers_counts.sort_values(by='EmailsReceived', ascending=False)

# Get the top 10 receivers
top_receivers = receivers_counts.head(10)

# Plot for receivers
plt.figure(figsize=(12, 6))
plt.bar(top_receivers['MetadataTo'], top_receivers['EmailsReceived'])
plt.ylabel('Number of Emails Received')
plt.title('Top 10 Recipients of Emails', fontsize=16)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Function to tokenize and lemmatize text
def tokenize_and_lemmatize(text):
    tokens = word_tokenize(text)
    lemmas = [stemmer.stem(token.lower()) for token in tokens if token.isalpha() and token.lower() not in stop_words]
    return lemmas

# Tokenize and lemmatize the 'ExtractedBodyText' column
emails['ProcessedText'] = emails['ExtractedBodyText'].apply(lambda x: tokenize_and_lemmatize(x) if isinstance(x, str) else [])

# Display the DataFrame with the processed text
print(emails[['ExtractedBodyText', 'ProcessedText']].head())
# Out:
#                                                      ExtractedBodyText  \
# ExtractedDateSent
# 2012-09-12 10:16:00                                               null
# NaT                  B6\r\nThursday, March 3, 2011 9:45 PM\r\nH: La...
# 2012-09-12 11:52:00                                                Thx
# NaT                                                               null
# NaT                  H <hrod17@clintonemail.com>\r\nFriday, March 1...
#
#                                                          ProcessedText
# ExtractedDateSent
# 2012-09-12 10:16:00                                                 []
# NaT                  [thursday, march, pm, h, latest, syria, aid, q...
# 2012-09-12 11:52:00                                              [thx]
# NaT                                                                 []
# NaT                  [h, friday, march, pm, huma, abedin, fw, h, la...

# %% [markdown]
# Length of emails

# %% [markdown]
# - There are many emails that do not have body text (NaN), which is the possible reason for the highest bar graph. As the number of words increase, the graph decreases exponentially.
# - The downward trend of the graph seems plausible considering that emails can be written casually and the a few of most frequently appearing texts are 'fyi,' 'ok,' and 'pls print.'
# - However, there may be some errors and bias in tokenizing and lemmatizing considering that there are over 400 emails that have 2 words

# %%
import matplotlib.pyplot as plt

# Check for NaN values in 'ExtractedBodyText' and fill them with an empty string
emails['ExtractedBodyText'].fillna('', inplace=True)

# Calculate the length of each email (number of words)
emails['EmailLength'] = emails['ExtractedBodyText'].apply(lambda x: len(str(x).split()))

# Plot the distribution of email lengths
plt.figure(figsize=(12, 6))
plt.hist(emails['EmailLength'], bins=50, color='skyblue', edgecolor='black')
plt.xlabel('Email Length (Number of Words)')
plt.ylabel('Frequency')
plt.title('Distribution of Email Lengths')
plt.grid(axis='y', alpha=0.75)
plt.show()

# %%
# Set a cap for email length
cap = 100
filtered_lengths = [length for length in emails['EmailLength'] if length <= cap]

# Create a histogram
plt.figure(figsize=(12, 6))
plt.hist(filtered_lengths, bins=50, color='skyblue', edgecolor='black', alpha=0.7)
plt.xlabel('Email Length (Number of Words)')
plt.ylabel('Frequency')
plt.title('Distribution of Email Lengths')
plt.grid(axis='y', alpha=0.75)
plt.show()

# %%
# Set a cap for email length
cap = 10
filtered_lengths = [length for length in emails['EmailLength'] if length <= cap]

# Create a histogram
plt.figure(figsize=(12, 6))
plt.hist(filtered_lengths, bins=50, color='skyblue', edgecolor='black', alpha=0.7)
plt.xlabel('Email Length (Number of Words)')
plt.ylabel('Frequency')
plt.title('Distribution of Email Lengths')
plt.grid(axis='y', alpha=0.75)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Create a histogram with log scale
plt.figure(figsize=(12, 6))
plt.hist(filtered_lengths, bins=50, color='skyblue', edgecolor='black', alpha=0.7)
plt.yscale('log')  # Set y-axis scale to log
plt.xlabel('Email Length (Number of Words)')
plt.ylabel('Frequency')
plt.title('Distribution of Email Lengths (Log Scale)')
plt.grid(axis='y', alpha=0.75)
plt.show()

# %%
import pandas as pd

# First, filter out emails with missing body text
filtered_emails = emails.dropna(subset=['ExtractedBodyText'])

# Calculate the length of each email
filtered_emails['EmailLength'] = filtered_emails['ExtractedBodyText'].apply(lambda x: len(x.split()))

# Calculate the average email length for each sender
avg_length_per_sender = filtered_emails.groupby('MetadataFrom')['EmailLength'].mean().reset_index()

# Sort senders by average email length in descending order
top_senders_lengthy_emails = avg_length_per_sender.sort_values(by='EmailLength', ascending=False).head(10)

# Display the top 10 senders of lengthy emails
print(top_senders_lengthy_emails)
# Out:
#             MetadataFrom  EmailLength
# 188     Philippe, Reines  4887.000000
# 46               Chelsea  3492.000000
# 133       Lewis, Reta Jo  2336.000000
# 214                Sandy  2288.000000
# 175      Newmyer, Jackie  1129.250000
# 53     Coleman, Claire L  1040.833333
# 199  Reines, Phillippe I  1026.000000
# 196     Reines, Philippe   801.000000
# 78       Farrow, Jeffrey   716.000000
# 285             sbwhoeop   710.079114

# %%
# Plot the top 10 senders of lengthy emails
plt.figure(figsize=(12, 6))
plt.bar(top_senders_lengthy_emails['MetadataFrom'], top_senders_lengthy_emails['EmailLength'])
plt.xlabel('Sender')
plt.ylabel('Average Email Length')
plt.title('Top 10 Senders of Lengthy Emails')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# Distrubution of Emails over Time
# - From 2009 to 2013, the graph shows who is the top sender of emails. The results are consistent with the findings regarding top senders and receivers, with all of the names of the graph centering around Mills, Clinton, Sullivan, and Abedin.
# - The graph shows the top sender per month if there are valid data.
# - Seeing that the top senders often last for more than a month, even up to 5 months, it is possible to suspect that Clinton often consults a single person or only a number of people at times or that the relationships with people change over time.

# %%
import pandas as pd
import matplotlib.pyplot as plt

emails = pd.read_csv('Emails.csv')

# Convert 'ExtractedDateSent' to datetime format
emails['ExtractedDateSent'] = pd.to_datetime(emails['ExtractedDateSent'], errors='coerce')

# Drop rows where 'ExtractedDateSent' is missing or not a valid date
emails = emails.dropna(subset=['ExtractedDateSent'])

# Group by sender and time period (e.g., month)
emails['YearMonth'] = emails['ExtractedDateSent'].dt.to_period('M')
grouped = emails.groupby(['YearMonth', 'MetadataFrom']).size().reset_index(name='EmailsSent')

# Find the sender who sent the most emails in each time period
idx = grouped.groupby(['YearMonth'])['EmailsSent'].transform(max) == grouped['EmailsSent']
top_senders = grouped[idx]

# Plot the distribution of emails over time
plt.figure(figsize=(10, 12))
plt.hist(emails['ExtractedDateSent'], bins=50, color='skyblue', alpha=0.7, orientation='horizontal')
plt.ylabel('Date')
plt.xlabel('Number of Emails')
plt.title('Distribution of Emails Over Time')

# Mark the top sender for each time period
for _, row in top_senders.iterrows():
    plt.axhline(row['YearMonth'].to_timestamp(), color='red', linestyle='dashed', linewidth=1)
    plt.text(50, row['YearMonth'].to_timestamp(), row['MetadataFrom'], fontsize=8)

plt.legend(['Emails', 'Top Sender'])
plt.tight_layout()
plt.show()

# %% [markdown]
# **(3) TF-IDF**

# %% [markdown]
# Using NLP techniques such as TF-IDF or count vectorization generate a list of the five TF-IDF terms that best describe the emails.

# %% [markdown]
# A variety of methods were used to generate terms that describe the topics. However, most of the words are filler words like fyi, ok, thi, pm, ye. Using SpaCy to remove all non-noun tokens may be a good idea.

# %%
# Create an empty list to store the lemmatized tokens
lemmas_list = []

# Iterate over each item in the corpus
for docID, content in corpus:
    # Apply tokenize_lemmatize_text to lemmatize the content
    lemmas = tokenize_lemmatize_text(content)
    
    # Append the lemmatized tokens to the list as a single tuple (docID, lemmas)
    lemmas_list.append((docID, lemmas))

# Create a DataFrame from the list of tuples
lemmas_df = pd.DataFrame(lemmas_list, columns=['docID', 'lemmas'])

# %%
# Create an empty list to store the lemmatized tokens
lemmas_list = []

# Iterate over each item in the corpus
for docID, content in corpus:
    # Apply tokenize_lemmatize_text to lemmatize the content
    lemmas = tokenize_lemmatize_text(content)
    
    # Append the lemmatized tokens to the list as a single tuple (docID, lemmas)
    lemmas_list.append((docID, lemmas))

# Create a DataFrame from the list of tuples
lemmas_df = pd.DataFrame(lemmas_list, columns=['docID', 'lemmas'])

# Continue with the TF-IDF calculations
from sklearn.feature_extraction.text import TfidfVectorizer

# Combine lemmatized tokens into a single string per document
lemmas_df['text'] = lemmas_df['lemmas'].apply(lambda x: ' '.join(x))

# Create TF-IDF vectorizer
vectorizer = TfidfVectorizer()
tfidf_matrix = vectorizer.fit_transform(lemmas_df['text'])

# Create DataFrame with TF-IDF values
tfidf_df = pd.DataFrame(tfidf_matrix.toarray(), columns=vectorizer.get_feature_names_out())

# Add 'docID' column to the TF-IDF DataFrame
tfidf_df['docID'] = lemmas_df['docID']

# %% [markdown]
# TF-IDF

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# Extract lemmatized text from the DataFrame
lemmatized_text = lemmas_df['lemmas'].apply(lambda lemmas: ' '.join(lemmas))

# TF-IDF Vectorization
tfidf_vectorizer = TfidfVectorizer(stop_words='english')
tfidf_matrix = tfidf_vectorizer.fit_transform(lemmatized_text)

# Get the top terms based on their average TF-IDF scores across documents
average_tfidf_scores = tfidf_matrix.mean(axis=0).A1
top_terms_indices = average_tfidf_scores.argsort()[-5:][::-1]
top_terms = [tfidf_vectorizer.get_feature_names_out()[idx] for idx in top_terms_indices]

# Display the top 5 terms
print("Top 5 TF-IDF Terms:", ', '.join(top_terms))
# Out:
# Top 5 TF-IDF Terms: fyi, ok, thi, pm, ye

# %% [markdown]
# Count Vectorization

# %%
from sklearn.feature_extraction.text import CountVectorizer

# Extract lemmatized text from the DataFrame
lemmatized_text = lemmas_df['lemmas'].apply(lambda lemmas: ' '.join(lemmas))

# Count Vectorization
count_vectorizer = CountVectorizer(stop_words='english')
count_matrix = count_vectorizer.fit_transform(lemmatized_text)

# Get the top terms based on their total count across documents
total_counts = count_matrix.sum(axis=0).A1
top_terms_indices = total_counts.argsort()[-5:][::-1]
top_terms = [count_vectorizer.get_feature_names_out()[idx] for idx in top_terms_indices]

# Display the top 5 terms
print("Top 5 Count Vectorization Terms:", ', '.join(top_terms))
# Out:
# Top 5 Count Vectorization Terms: thi, wa, hi, state, ha

# %% [markdown]
# Latent Semantic Analysis (LSA)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD

# Extract lemmatized text from the DataFrame
lemmatized_text = lemmas_df['lemmas'].apply(lambda lemmas: ' '.join(lemmas))

# TF-IDF Vectorization
tfidf_vectorizer = TfidfVectorizer(stop_words='english')
tfidf_matrix = tfidf_vectorizer.fit_transform(lemmatized_text)

# Latent Semantic Analysis (LSA)
num_topics = 5  # Specify the number of topics
lsa_model = TruncatedSVD(n_components=num_topics)
lsa_matrix = lsa_model.fit_transform(tfidf_matrix)

# Get the top terms for each topic
terms = tfidf_vectorizer.get_feature_names_out()
top_terms_indices = lsa_model.components_.argsort(axis=1)[:, ::-1]
top_terms = [[terms[idx] for idx in row[:5]] for row in top_terms_indices]

# Display the top terms for each topic
for i, topic_terms in enumerate(top_terms):
    print(f"Topic {i + 1}: {', '.join(topic_terms)}")
# Out:
# Topic 1: fyi, fw, cheryl, millscd, pm
# Topic 2: ok, talk, pm, thi, thx
# Topic 3: pm, print, thi, pl, secretari
# Topic 4: print, pl, pi, copi, hrc
# Topic 5: ye, thx, print, pl, work

# %% [markdown]
# Word Embeddings (Word2Vec or GloVe)

# %%
from gensim.models import Word2Vec

# Extract lemmatized tokens from the DataFrame
lemmatized_tokens = lemmas_df['lemmas'].tolist()

# Train Word2Vec model
word2vec_model = Word2Vec(sentences=lemmatized_tokens, vector_size=100, window=5, min_count=1, workers=4)

# Get the most similar terms for each term in the vocabulary
similar_terms = {term: [similar[0] for similar in word2vec_model.wv.most_similar(term, topn=5)] for term in word2vec_model.wv.index_to_key}

# Display the similar terms for each term
for term, similar_list in similar_terms.items():
    print(f"{term}: {', '.join(similar_list)}")
# Out:
# thi: done, great, veri, anyth, give
# wa: msnbc, three, run, snub, brown
# hi: snub, mr, wa, bush, barack
# state: rambouillet, memorandum, rockefel, build, nypd
# ha: critic, term, war, becom, decad
# pm: franklin, pool, luncheon, ceremoni, recept
# call: op, sheet, schedul, phone, confirm
# would: like, could, say, way, never
# secretari: hillari, offic, rodham, confer, napolitano
# time: today, minut, ask, later, trip
# work: well, need, readi, address, appreci
# offic: confer, brief, ahmet, gate, davutoglu
# said: mr, dure, msnbc, morsi, petraeu
# obama: barack, bush, hi, presid, elect
# depart: doc, air, fraught, privat, rout
# presid: barack, bush, mr, obama, dure
# one: made, never, say, slip, abl
# new: york, improb, upstat, nark, yorker
# meet: espinosa, offic, phone, confer, brief
# also: proxim, speak, assum, set, prepar
# hou: nocol, ellip, senat, white, chatham
# like: happen, might, someth, anyon, would
# get: sure, go, hope, see, got
# us: issu, help, need, pakistan, direct
# say: would, one, never, take, happen
# want: know, let, go, anyth, discuss
# american: govern, support, public, protect, econom
# govern: econom, american, public, develop, afghan
# year: month, two, decad, ago, past
# see: thx, u, sure, send, get
# fyi: b, print, mon, rc, justin
# peopl: world, chang, becau, countri, progress
# need: work, well, help, us, much
# h: decemb, saturday, friday, huma, fw
# go: tri, anyth, get, done, look
# nation: forc, council, secur, rockefel, global
# know: let, want, discuss, hope, anyth
# polit: public, spectrum, reconcil, among, million
# make: better, ani, thing, way, doe
# support: war, american, role, afghanistan, ntc
# clinton: hillari, calderon, espinosa, gate, vilsack
# think: veri, thing, done, much, anyth
# talk: today, ask, back, soon, u
# could: abl, never, step, move, might
# secur: nation, global, forc, develop, council
# parti: percent, voter, major, democrat, reform
# issu: pakistan, us, region, engag, israel
# today: ask, talk, soon, back, yang
# first: dure, calderon, said, morsi, mr
# right: world, china, interest, peopl, lend
# polici: emeritu, council, relat, servic, intergovern
# last: next, ago, day, week, wa
# back: talk, soon, come, today, hear
# ani: make, keep, idea, realli, easier
# republican: democrat, congress, heartbeat, vote, wld
# countri: commit, world, must, peopl, china
# democrat: republican, congress, elect, voter, parti
# foreign: prime, khar, guild, minist, emeritu
# senat: white, nocol, hou, nanci, chatham
# unit: revit, apartheid, secur, inspector, forc
# day: earlier, hour, next, week, come
# two: past, three, sinc, five, ago
# may: sid, doug, latest, tue, memo
# women: commun, effort, afghan, capac, protect
# onli: deal, seem, job, less, posit
# way: better, doe, whi, realli, could
# come: back, tri, go, proxim, earlier
# help: import, chang, china, opportun, mean
# report: review, tauscher, rice, madelein, attend
# good: forward, great, hope, sure, anyth
# even: seem, abl, actual, never, move
# take: happen, tri, step, lot, put
# group: includ, local, educ, agricultur, militari
# veri: think, much, thing, done, lot
# ask: today, talk, back, soon, yang
# vote: wld, vol, voter, democrat, republican
# world: china, countri, must, interest, commit
# room: joint, madison, prece, monro, spray
# offici: senior, advi, gener, defen, top
# week: day, next, month, supplement, hour
# includ: local, agricultur, group, civilian, organ
# white: chatham, senat, hou, shriek, nocol
# israel: effort, commit, palestinian, arab, futur
# leader: campaign, obstruct, major, control, among
# mani: believ, progress, deal, everi, job
# well: lot, idea, appreci, excit, keep
# becau: differ, deal, seem, mean, chang
# minist: khar, prime, deputi, noer, guild
# washington: pin, hotel, sharon, ppl, arriv
# public: ntc, militari, econom, civilian, fund
# much: lot, veri, realli, think, better
# elect: congress, candid, midterm, rafsanjani, campaign
# discuss: let, tell, hope, know, give
# administr: ha, barack, campaign, bush, leader
# case: doc, daylight, usaid, chihuahua, canvass
# gener: serv, aid, advi, paramet, command
# thank: intermitt, plea, email, pleasur, send
# let: discuss, know, want, sure, hope
# intern: global, forc, agenc, institut, develop
# befor: hour, leav, tonight, hear, yang
# inform: redact, foia, sensit, waiver, unclassifi
# bill: fl, pelosi, msnbc, pass, aliyev
# use: form, allow, side, defin, play
# plan: versu, direct, deplor, bolster, necess
# part: bleak, mental, rep, hvn, moratorium
# tomorrow: afternoon, u, check, draft, anytim
# point: el, anoth, still, away, decid
# privat: resid, laguardia, street, en, rout
# chang: mean, becau, clear, progress, differ
# develop: econom, diplomaci, afghan, global, stabil
# tri: anyth, someth, give, done, go
# confer: offic, deputi, gate, daili, brief
# forc: global, agenc, intern, develop, institut
# staff: gate, chief, oval, floor, brief
# next: day, earlier, ago, come, hour
# afghanistan: israel, commit, alli, america, role
# arriv: marriott, en, airport, hotel, francisco
# w: schedul, afternoon, morn, tomorrow, molho
# effort: commun, arab, protect, israel, creat
# agreement: sensit, hebron, diagnost, redact, hillsborough
# follow: note, dan, raj, add, attach
# peac: effort, commit, commun, israel, interest
# doe: way, better, whi, mean, realli
# told: woodward, team, urib, preval, spoke
# power: increa, economi, conflict, face, role
# made: one, clear, onli, never, posit
# look: happen, thing, done, might, tri
# still: someth, chanc, nobodi, might, find
# speech: earli, hear, hour, cd, tonight
# isra: haitian, program, expand, establish, organ
# war: role, strong, face, critic, million
# china: must, interest, commit, futur, solut
# percent: parti, voter, major, democrat, reform
# militari: civilian, diplomat, includ, ntc, organ
# member: campaign, candid, machineri, primari, held
# cheryl: fw, friday, mill, saturday, h
# date: dept, doc, produc, museum, pentagon
# former: vice, senior, butt, chief, top
# sinc: five, lost, decad, six, half
# hope: give, anyth, great, sure, tell
# end: accomplish, ahead, big, offer, place
# subject: hillsborough, comm, dca, chatter, lausann
# health: reform, care, economi, rate, lead
# press: outer, joint, beast, prece, room
# best: messag, catch, sorri, stuff, nice
# thing: done, think, look, happen, better
# give: anyth, great, thought, tri, tell
# rout: en, airport, resid, arriv, air
# huma: sent, wrote, h, decemb, friday
# deal: believ, onli, seem, job, posit
# en: rout, airport, arriv, resid, andrew
# start: find, stori, someon, excit, assum
# dure: mr, bush, intim, calderon, petraeu
# anoth: decid, away, el, suggest, mistak
# benghazi: select, comm, cordoba, whip, facto
# iran: diplomat, civilian, relationship, organ, alli
# interest: must, commit, solut, futur, solv
# major: among, independ, reform, conserv, control
# put: question, step, hard, togeth, everyth
# sent: huma, wrote, decemb, h, monday
# around: bring, togeth, clearli, stand, rai
# assist: ecial, special, ambassador, rodham, valmoro
# import: opportun, kind, easier, real, share
# send: thx, u, draft, check, email
# build: command, repr, rockefel, intergovern, oper
# monday: sunday, wrote, tuesday, sent, huma
# great: thought, give, ca, anyth, wo
# hillari: secretari, rodham, napolitano, brief, espinosa
# care: health, reform, rate, jalil, onli
# continu: futur, ensur, valu, partner, greatest
# produc: dept, museum, select, cordoba, plain
# move: abl, actual, whether, away, everyth
# believ: progress, posit, deal, problem, achiev
# email: send, cdm, copi, thx, draft
# campaign: leader, member, primari, obstruct, conserv
# job: less, spend, posit, without, deal
# month: year, two, three, one, five
# resid: privat, laguardia, en, rout, avenu
# america: protect, creat, prosper, commit, conflict
# attack: inten, key, popular, taliban, rule
# econom: develop, govern, public, afghan, includ
# question: put, agr, ahead, knew, someon
# place: long, ahead, ever, offer, turn
# statement: spoke, shortli, travel, wh, cancel
# messag: best, sorri, stuff, catch, feedback
# commun: stabl, effort, protect, arab, creat
# david: joe, podesta, ladi, stanley, shelbi
# close: mideast, difficulti, choo, taken, doubt
# seem: differ, even, deal, without, clear
# fw: mill, sullivanjj, sullivan, august, prein
# news: tv, microsoft, bin, stern, ho
# congress: elect, candid, democrat, republican, midterm
# number: suggest, option, tough, instead, expect
# ok: ye, wh, asap, berri, weekend
# sure: hope, get, see, jm, forward
# sunday: tuesday, monday, friday, thursday, saturday
# respon: valu, effect, concern, greatest, goal
# ye: ok, btw, edit, tonight, info
# person: onc, agr, none, meant, bit
# team: congratul, rice, met, familiar, visit
# set: unga, cancel, isabel, fine, thru
# friday: decemb, saturday, thursday, sunday, tuesday
# relea: cc, millscd, apr, abedin, fw
# home: guidanc, holbrook, sometim, connect, spoken
# might: someth, anyon, still, happen, chanc
# mill: fw, sullivanjj, sullivan, j, jacob
# pl: cdm, pi, thx, copi, info
# palestinian: arab, israel, effort, focu, ensur
# print: memo, tue, lissa, mon, justin
# long: place, matter, ever, offer, rai
# negoti: focu, solut, requir, strong, success
# posit: deci, seriou, far, believ, without
# provid: region, nuclear, establish, capabl, democraci
# thought: great, ca, probabl, give, someth
# process: achiev, benefit, problem, fundament, use
# among: independ, major, control, conserv, advantag
# show: surpri, stuck, contest, felt, break
# lead: opinion, advantag, freez, rate, result
# note: follow, raj, campbel, attach, birthday
# recent: sever, disastr, sinc, announc, petraeu
# ambassador: special, dialogu, ecial, envoy, strateg
# region: nuclear, provid, diplomaci, capac, commun
# sensit: redact, agreement, foia, inform, unclassifi
# senior: top, advi, offici, advisor, vice
# post: et, richard, editori, tape, l
# global: intern, forc, agenc, develop, elev
# oper: integr, gender, hemisph, servic, expert
# accord: heavili, millennium, command, qaeda, union
# select: benghazi, cordoba, whip, produc, gingrich
# tell: readi, give, feedback, trip, everyon
# run: cameron, brown, unfortun, petraeu, circl
# haiti: lanka, sri, taught, hiker, access
# morn: afternoon, draft, w, tomorrow, copi
# possibl: noth, everyth, explain, exactli, substanc
# thursday: saturday, friday, tuesday, sunday, decemb
# organ: program, civilian, establish, author, partnership
# whi: differ, way, feel, seem, better
# conserv: centrist, popular, independ, control, among
# live: effect, greatest, partner, goal, respon
# got: sorri, tonight, cd, feedback, hear
# book: headlin, rumor, origin, defer, blank
# becom: key, critic, within, agenda, requir
# must: commit, futur, solut, interest, china
# author: environ, organ, central, contribut, program
# forward: anyth, done, hope, good, thing
# afghan: capac, stabl, protect, commun, prosper
# aid: advi, machineri, dispatch, execut, presidenti
# famili: often, voic, third, shift, warn
# doc: date, dept, rout, en, case
# thx: send, pl, cdm, draft, check
# find: someon, probabl, still, someth, ca
# east: middl, multilat, center, gender, servic
# critic: becom, leadership, key, term, success
# servic: oper, hemisph, gender, integr, relat
# dept: date, produc, doc, museum, committ
# million: economi, increa, power, advantag, face
# special: ambassador, envoy, ecial, bureau, conven
# septemb: octob, fwd, wednesday, novemb, prein
# poll: palin, labour, smone, gomorrah, unchang
# speak: prepar, trip, also, set, unga
# voter: parti, percent, unchang, reform, wld
# clear: mean, differ, posit, seem, never
# reach: qddr, relay, declan, kurt, isabel
# center: sector, multilat, fellowship, caribbean, street
# problem: achiev, progress, fight, valu, solut
# agr: onc, obviou, explain, confu, answer
# york: zealand, arriv, airport, washington, marriott
# abedin: cc, fw, august, ebel, januari
# daili: deputi, gate, envoy, bilat, conven
# strategi: troop, european, crisi, leadership, dealt
# hrc: philipp, cheri, neera, blackberri, lissa
# done: anyth, thing, tri, happen, think
# mr: bush, dure, barack, intim, snub
# june: februari, januari, april, oct, cheri
# direct: saddam, proud, pakistan, morocco, deplor
# comm: benghazi, select, facto, subject, demograph
# human: commun, protect, stabl, effort, sustain
# yet: whatev, short, someon, fuck, judgment
# read: info, traffic, edit, sorri, nice
# final: bunch, el, coupl, heard, decid
# name: amaz, abba, quot, gave, asid
# result: movement, deficit, healthcar, inten, advantag
# idea: keep, realli, hard, lot, ca
# waiver: foia, redact, inform, sensit, diagnost
# plea: intermitt, thank, immedi, pleasur, woodard
# sid: memo, maggi, latest, b, print
# commit: must, futur, interest, america, solut
# wednesday: septemb, octob, prein, fwd, saturday
# mean: chang, clear, difficult, differ, becau
# redact: foia, waiver, sensit, inform, unclassifi
# tuesday: sunday, thursday, saturday, friday, monday
# keep: idea, hard, realli, lot, easier
# foia: redact, waiver, inform, sensit, unclassifi
# better: way, realli, doe, hard, whi
# concern: respon, effect, goal, toler, valu
# law: growth, sustain, reduc, civil, threat
# role: creat, power, alli, america, toward
# top: advisor, pentagon, senior, lisbon, butt
# far: real, preci, seriou, without, big
# diplomat: iran, militari, civilian, author, alli
# mcchrystal: suggest, mistak, number, none, second
# visit: donilon, met, rice, jone, hagu
# later: finish, hour, unga, spoke, set
# address: everyon, appreci, rest, folk, prepar
# current: career, ambit, reject, pursu, acknowledg
# repr: command, serv, reagan, tackl, silent
# fund: promot, social, reconcili, empow, expand
# pakistan: engag, relationship, partner, mission, un
# saturday: decemb, friday, thursday, h, prein
# view: demand, extrem, skeptic, mandat, desir
# brief: davutoglu, photo, gibb, joint, press
# schedul: w, confirm, sheet, bb, kouchner
# night: earli, weekend, late, backdrop, hour
# head: afterward, behalf, admir, deleg, pick
# diplomaci: nuclear, region, stabil, capac, program
# media: school, expan, outreach, communist, link
# arab: democraci, protect, ensur, effort, creat
# base: univ, sector, pjak, institut, integr
# without: far, spend, big, preci, seriou
# financ: led, launch, function, intellig, conduct
# u: send, tomorrow, check, thx, berri
# happen: look, might, anyon, done, someth
# suggest: tough, expect, number, option, surpri
# cdm: pl, pi, thx, info, copi
# presidenti: aid, advi, top, execut, pentagon
# settlement: increa, growth, digniti, sustain, fundament
# reform: major, rate, among, independ, lead
# august: prein, januari, fw, februari, abedin
# middl: east, gender, integr, servic, intern
# trip: tell, speak, prepar, saw, everyon
# term: critic, everi, becom, agenda, success
# leadership: critic, key, challeng, becom, dealt
# advi: biden, aid, presidenti, top, senior
# three: six, five, eight, half, fifti
# announc: acknowledg, came, promi, embarrass, cabinet
# compani: social, feder, islam, contribut, tool
# hold: robinson, left, friend, advic, event
# offer: turn, matter, quickli, strength, outcom
# john: harri, evngl, staffer, mitch, mitt
# receiv: ann, q, craig, page, chat
# travel: raj, mtg, lavrov, avail, ellen
# creat: protect, arab, prosper, ensur, focu
# differ: difficult, seem, whi, mean, big
# univ: institut, base, reagan, advisori, pjak
# program: organ, establish, partnership, haitian, agricultur
# institut: univ, multilat, base, sector, integr
# expect: tough, suggest, option, stuck, away
# focu: ensur, democraci, arab, creat, toward
# candid: boehner, elect, primari, congress, rafsanjani
# draft: copi, afternoon, check, send, thx
# school: media, studi, journalist, revolutionari, link
# fact: especi, side, coalit, play, shape
# march: januari, april, bam, februari, nov
# sullivan: j, sullivanjj, fw, jacob, fwd
# iraq: toward, alli, approach, respect, prosper
# leav: finish, mayb, hour, fine, hear
# reason: feel, definit, actual, certainli, littl
# side: fact, coalit, play, cut, alien
# understand: stand, seriou, deci, fight, clearli
# effect: live, respon, goal, greatest, concern
# chief: oval, staff, former, subcommitt, monro
# committ: presidenti, museum, pillar, produc, longworth
# local: includ, agricultur, civilian, organ, author
# hear: tonight, soon, thru, cancel, earli
# friend: robinson, amaz, name, event, gave
# relat: ministri, indonesian, servic, expert, nato
# turn: offer, accomplish, quickli, strength, quit
# comment: apolog, quick, summari, holiday, ill
# small: princip, centcom, deleg, aipac, eu
# action: ambigu, rebuild, object, chine, basi
# line: listen, felt, answer, full, mind
# face: economi, fundament, increa, attitud, defin
# remain: seek, encourag, accept, comprehen, advanc
# council: intergovern, multilat, caribbean, rockefel, servic
# earli: weekend, tonight, hear, speech, wh
# netanyahu: biden, ehud, olmert, appoint, weekli
# togeth: hard, put, easier, noth, step
# novemb: octob, septemb, april, march, june
# given: shape, life, deserv, coalit, demonstr
# cour: succeed, articul, attent, longer, comfort
# serv: command, forg, transit, repr, armi
# nuclear: diplomaci, region, stabil, provid, capac
# everi: term, less, posit, fight, deci
# alreadi: wrong, explain, rai, obviou, ever
# stori: sound, love, anyway, yet, miss
# sever: recent, announc, close, acknowledg, petraeu
# deci: seriou, posit, side, alien, fact
# though: alway, argument, quit, narr, wor
# enough: split, labour, tot, tori, sixti
# list: thru, grid, tonit, plane, cancel
# treati: marshal, photo, robert, hall, weekli
# big: seriou, difficult, alway, without, sen
# citi: foundat, research, scientist, school, armi
# never: step, whether, abl, slip, big
# step: never, hard, put, abl, big
# prime: foreign, khar, minist, guild, deputi
# un: throughout, climat, europ, facil, structur
# futur: must, commit, continu, solut, interest
# whether: abl, knew, unfold, exactli, nobodi
# share: risk, concern, resolv, action, area
# past: five, spent, eight, everi, six
# confirm: sheet, schedul, sept, op, yang
# http: rein, sep, mchale, toivnf, berger
# key: becom, inten, crisi, attack, critic
# relationship: iran, alli, approach, iraq, pakistan
# letter: wed, revi, derek, yesterday, lobo
# busi: pakistani, vision, pursu, palau, personnel
# economi: face, increa, fundament, power, attitud
# koch: allianc, claim, transform, combin, lie
# interview: mitchel, lunch, conf, pack, potu
# high: internet, ii, purcha, deliveri, type
# check: shaun, afternoon, anytim, draft, ok
# left: event, repli, vacat, gore, karl
# propo: period, learn, singapor, tone, welcom
# polic: network, cultur, islam, knowledg, recoveri
# return: sometim, paper, tom, yesterday, oa
# order: combat, task, account, impo, freedom
# bush: mr, dure, barack, aid, member
# jake: updat, print, memo, wrote, lissa
# claim: transform, industri, koch, liber, faction
# wrote: monday, huma, sunday, sent, decemb
# larg: account, presenc, throughout, worldwid, contribut
# allow: signif, play, compromi, requir, confid
# hour: hear, earli, tonight, speech, leav
# play: signif, allow, coalit, fact, demonstr
# review: eikenberri, london, brazilian, report, video
# appear: behind, appar, conclu, stanc, voic
# floor: monro, room, auditorium, staff, madison
# north: reconstruct, humanitarian, energi, applic, reduct
# challeng: consid, involv, principl, requir, respect
# feel: actual, reason, anyon, whi, whether
# ago: past, two, earlier, three, five
# juli: strobe, june, februari, lew, cheri
# initi: terror, approach, european, individu, implement
# sign: sean, data, refer, quot, abba
# event: karl, rememb, proceed, hit, delay
# pass: anoth, clotur, dodd, decid, version
# april: januari, februari, june, march, octob
# soon: asap, hear, thru, cancel, wh
# januari: februari, april, june, august, pir
# libya: newli, glenn, bid, favorit, stuart
# lot: realli, idea, hard, keep, much
# georg: biden, butt, weekli, top, appoint
# less: spend, job, side, fact, especi
# life: risk, condit, violenc, depend, area
# strateg: nonprolif, bureau, albright, undersecretari, keynot
# ad: conclu, behind, predict, appear, wfp
# least: expect, option, stuck, almost, tough
# ca: someth, chanc, thought, might, wo
# success: requir, confid, defin, respect, challeng
# increa: power, economi, face, fundament, settlement
# begin: quickli, ever, true, comfort, save
# brown: petraeu, run, cameron, bite, cabinet
# j: jacob, sullivanjj, sullivan, fwd, mill
# jewish: promot, law, stabil, sustain, civil
# approach: respect, initi, centuri, partner, challeng
# word: whatev, absolut, line, simpl, god
# memo: print, tue, lissa, mon, sid
# went: rememb, kick, either, hit, repli
# system: growth, sustain, afford, law, reduc
# rai: alreadi, ever, explain, matter, bring
# toward: iraq, respect, initi, strengthen, focu
# found: compar, troubl, populist, arrest, mount
# onc: meant, agr, answer, moment, mind
# airport: tail, air, andrew, en, arriv
# heard: bunch, calm, miss, oh, piec
# consid: challeng, principl, involv, advanc, substanti
# decemb: friday, saturday, h, thursday, sunday
# came: name, smile, karzai, colleagu, robinson
# rate: lead, opinion, independ, split, jalil
# prepar: saw, folk, enjoy, till, everyon
# real: far, kind, genuin, seriou, ordinari
# progress: problem, achiev, believ, solut, fight
# someth: might, still, ca, probabl, anyon
# copi: draft, pl, cdm, updat, send
# connect: whenev, home, sometim, roll, document
# across: muslim, feder, terror, societi, presenc
# control: popular, inten, independ, conserv, bipartisan
# remark: appoint, weekli, envoy, yu, kevin
# jacob: j, sullivanjj, sullivan, mill, fwd
# fight: problem, strong, success, defin, alien
# opportun: import, share, achiev, problem, toler
# violenc: condit, area, natur, risk, life
# men: histor, dollar, wage, deficit, extrem
# kill: dramat, higher, huge, revolut, brand
# money: depend, compromi, larger, ground, scale
# approv: disapprov, palin, conserv, centrist, demograph
# seen: absolut, word, alon, whatev, judgment
# op: sheet, call, phone, confirm, bb
# pi: cdm, pl, attach, maggi, ms
# open: celebr, polish, marin, russian, deni
# affair: director, defen, pacif, caribbean, center
# littl: honest, bad, substanc, certainli, possibl
# situat: determin, kenya, vision, acknowledg, famili
# rather: succeed, attent, ultim, intent, beyond
# hand: push, concess, hurt, themselv, cut
# love: stori, miss, wo, explor, stuff
# sen: noth, certainli, explain, alway, kind
# fail: unlik, legisl, weak, frustrat, convinc
# present: shift, reflect, addit, will, directli
# articl: ft, pat, jan, confidenti, gmt
# contact: toiv, laszczych, joann, nora, immedi
# el: away, point, anoth, final, stick
# sourc: despit, consist, express, crisi, argu
# bring: clearli, rai, stand, ever, affect
# civilian: organ, iran, program, militari, author
# free: adjust, govt, road, otherwi, content
# jim: potu, tom, steinberg, cell, readout
# happi: thanksgiv, catch, kurt, wh, declan
# minut: fli, cell, menendez, shortli, return
# european: initi, environ, implement, crisi, terror
# educ: agricultur, includ, local, social, central
# addit: present, accommod, reflect, uighur, assess
# defen: affair, director, shadow, pacif, bureau
# movement: result, opinion, deficit, gain, trend
# lona: valmoro, lauren, wexler, fm, shuttl
# tea: rate, jalil, tot, enough, split
# matter: strength, offer, ever, rai, outcom
# hard: realli, idea, keep, togeth, noth
# rule: taliban, essenti, popul, common, measur
# conflict: increa, solv, ensur, greatest, power
# took: husband, carter, resign, ford, came
# phone: op, bb, call, mtg, mitchel
# strong: fight, success, respon, valu, requir
# photo: hall, seci, davutoglu, treati, cannon
# yesterday: michel, paper, shortli, return, mario
# howev: record, instead, choic, realiz, doubt
# millscd: abedinh, jul, reinesp, sullivanii, cc
# anyth: give, done, tri, great, thought
# within: becom, signif, terrorist, rival, consid
# realli: hard, idea, lot, keep, better
# octob: novemb, septemb, april, wednesday, prein
# street: convent, tbd, avenu, hardi, tn
# fm: turkish, susan, marti, dc, monica
# updat: print, lissa, memo, oscar, jake
# requir: success, allow, involv, confid, challeng
# stand: clearli, bring, understand, seriou, underscor
# dc: marti, fm, cathi, turkish, verveerm
# activ: trade, individu, freedom, threat, increasingli
# area: risk, violenc, condit, life, size
# act: emerg, student, deepli, reflect, tie
# taliban: essenti, domest, level, element, societi
# manag: armi, led, intellig, union, qaeda
# holbrook: home, congratul, sometim, spoken, connect
# immedi: urgent, marisa, inquiri, contact, woodard
# chine: basi, attent, object, exist, primarili
# describ: brother, era, urg, dismiss, openli
# deliv: guidanc, spoken, formal, pocket, chri
# histori: seek, grow, restor, threat, particularli
# director: affair, caribbean, pacif, center, street
# dinner: kouchner, fax, ny, potu, mtg
# write: rememb, hair, guidanc, brussel, forth
# partner: citizen, capabl, ensur, live, effect
# engag: pakistan, partner, capabl, action, transnat
# demand: view, defin, attitud, measur, confid
# protect: prosper, creat, arab, commun, america
# stop: although, space, style, translat, surviv
# second: howev, surpri, record, tough, mistak
# request: barak, ladi, kirk, pari, gen
# spend: less, without, far, job, narr
# bilat: camera, prece, joint, marshal, spray
# mention: wjc, deadlin, guy, download, miss
# mission: prioriti, invest, resourc, personnel, busi
# actual: feel, abl, unfold, whether, reason
# boehner: gop, midterm, seat, debat, filibust
# justic: environ, islam, employ, central, compani
# tonight: hear, ye, earli, ok, mariann
# alway: certainli, everyth, though, quit, narr
# figur: promin, meanwhil, surg, oppon, assembl
# tori: lose, split, parliament, over, rhetor
# richard: et, feltman, post, patrick, l
# seek: grow, restor, credibl, particular, particularli
# debat: defeat, black, fallen, fifti, gop
# command: repr, serv, armi, expert, forg
# level: individu, crisi, domest, taliban, element
# involv: principl, consid, measur, requir, signif
# bank: islam, social, societi, highest, buy
# threat: reduc, activ, prevent, histori, freedom
# project: root, lack, estim, poor, extremist
# abl: whether, move, everyth, actual, alway
# particip: innov, variou, deploy, outreach, link
# opinion: movement, lead, result, advantag, men
# either: suppo, rememb, mine, guy, closer
# tom: return, jim, eric, paper, mcguin
# late: revi, pc, torn, wed, iii
# alli: iraq, role, iran, relationship, toward
# four: twenti, seven, fiscal, dozen, nine
# labour: enough, motion, sixti, split, cent
# februari: januari, june, april, pir, cheri
# europ: task, technic, complex, lesson, climat
# exampl: absenc, illeg, student, northern, tie
# win: split, lose, tori, less, sixti
# avail: mtg, conf, lavrov, mitchel, potu
# societi: across, taliban, creation, feder, increasingli
# children: suffer, violent, reinforc, crime, soldier
# respect: approach, success, centuri, challeng, particularli
# limit: appli, relief, stress, identifi, model
# outsid: warn, conclud, guid, known, player
# away: expect, stick, short, wor, surpri
# full: listen, extend, easili, sort, god
# almost: howev, instead, doubt, second, record
# noth: sen, certainli, possibl, everyth, alway
# spoke: shortli, yesterday, unga, return, set
# establish: partnership, program, contribut, organ, expand
# india: coordin, morocco, proud, logist, indonesia
# troop: vision, busi, undermin, initi, advanc
# detail: reaction, track, flag, remind, sleep
# train: western, function, guard, arsen, transit
# favor: unfavor, palin, hrd, hvn, ganley
# fear: danger, lack, consequ, soldier, ground
# saw: prepar, deadlin, frankli, stuff, enjoy
# kind: sen, seriou, real, rai, difficult
# foundat: transit, train, latin, expert, citi
# arm: western, guard, function, target, worldwid
# ensur: partner, solv, focu, arab, continu
# per: cent, littl, honest, definit, firmli
# west: donat, began, ralli, tension, insult
# met: london, kabul, visit, brazilian, video
# held: blame, disastr, primari, elig, introduc
# blair: testimoni, voinovich, floor, auditorium, fax
# cameron: gore, embarrass, indic, run, unfortun
# jone: donilon, session, joe, appoint, visit
# death: grant, netherland, mere, paid, kept
# account: presenc, order, freedom, worldwid, larg
# potenti: count, factor, circumst, constitu, tax
# often: voic, warn, contend, oppo, lie
# b: mon, fyi, tue, doug, sid
# chanc: knew, exactli, still, anyon, ca
# terror: muslim, freedom, across, initi, feder
# add: plane, dan, kurt, grid, relay
# decid: corker, assum, anoth, gotten, bit
# deputi: daili, gate, conven, confer, shadow
# achiev: problem, progress, process, solut, fight
# regard: asia, turkey, cautiou, africa, korean
# along: refer, greec, routin, hondura, wear
# fax: dinner, catherin, lunch, ny, cell
# barack: presid, bush, obama, mr, hi
# south: professor, kurdish, commiss, african, locat
# armi: intellig, manag, expert, led, latin
# wjc: mention, mayb, download, deadlin, terrif
# young: danger, pressur, battl, poor, fear
# push: longer, quickli, hand, imagin, outcom
# earlier: decid, assum, proxim, corker, start
# respond: gone, door, hang, pull, altern
# northern: exampl, deep, abil, skill, student
# execut: fellow, caucu, ratifi, attorney, su
# via: jiloti, crowley, cingular, verizon, jilotylc
# gave: formal, regret, dress, sit, bahtiyar
# student: skill, heart, exploit, act, exampl
# piec: download, comment, miss, mention, oh
# decad: sinc, term, within, becom, agenda
# lost: fail, reelect, legisl, five, almost
# air: airport, tail, en, rout, andrew
# iranian: contract, islam, western, compani, network
# taken: agenda, grown, experi, difficulti, consid
# access: russia, haiti, standard, limit, relief
# independ: among, conserv, control, bipartisan, result
# voic: often, behind, warn, oppo, contend
# accept: seek, restor, enabl, remain, grow
# agenda: taken, trust, experi, consid, becom
# mark: expo, wilson, bloomberg, retir, johnson
# liber: lower, knesset, meanwhil, turnout, stimulu
# industri: perform, claim, pharmaceut, spread, activist
# afternoon: check, shaun, draft, tomorrow, morn
# muslim: across, feder, terror, presenc, freedom
# dollar: prevent, popul, desir, essenti, measur
# answer: meant, mind, obviou, line, whatev
# complet: sort, treat, symbol, light, harm
# democraci: arab, prosper, focu, protect, creat
# seriou: deci, big, far, kind, difficult
# latest: cfr, maggi, sandi, derek, r
# join: brought, acknowledg, main, budget, career
# petraeu: brown, cabinet, run, announc, close
# ireland: appeal, interact, lack, soldier, northern
# insid: assembl, analysi, promin, abandon, divid
# conver: outlin, chri, excel, brussel, memori
# ground: soldier, fear, exist, larger, suffici
# goal: effect, particularli, safeti, principl, respon
# corpor: wide, conduct, sought, employ, donor
# man: collap, gap, motiv, huge, disagr
# video: brazilian, bob, amb, min, london
# food: religi, greater, presenc, broader, combat
# promot: fund, expand, empow, stabil, civil
# branch: wit, instanc, boy, winner, deed
# stay: mayb, sleep, went, suppo, wjc
# gate: daili, deputi, weekli, confer, envoy
# improv: natur, encourag, danger, influenc, religion
# investig: donor, immigr, communist, assault, massiv
# instead: howev, choic, doubt, fair, neither
# experi: difficulti, agenda, taken, shift, persuad
# coordin: enhanc, humanitarian, postur, corp, resourc
# refer: celebr, coup, along, asid, greec
# crisi: level, element, individu, domest, undermin
# social: feder, compani, islam, across, muslim
# cut: shape, simpli, argument, coalit, outcom
# prevent: reduc, legitim, popul, equal, dollar
# africa: sri, notic, regard, korea, asia
# beck: thousand, partisan, cap, rural, birth
# jerusalem: libyan, reserv, cultur, doctrin, advocaci
# hill: upon, goldman, texa, assassin, edward
# record: howev, perhap, beat, realiz, neg
# someon: yet, find, exactli, short, whatev
# embassi: beij, russian, egyptian, polish, turkey
# islam: network, contract, feder, iranian, social
# perhap: record, break, uup, clegg, indic
# freedom: presenc, account, terror, order, impo
# ind: unemploy, men, wtbrnagn, over, rep
# behind: appear, appar, charact, voic, settl
# quit: alway, argument, though, outcom, narr
# lack: danger, fear, suffer, tie, consequ
# explain: everyth, alreadi, everybodi, obviou, alway
# feder: across, muslim, social, presenc, islam
# ever: quickli, mind, alreadi, strength, rai
# mitchel: potu, avail, lunch, conf, interview
# trade: individu, increasingli, activ, order, accept
# weapon: sanction, prevent, legitim, area, ingo
# gordon: brussel, alexand, quinn, tent, durbin
# especi: fact, coalit, cut, argument, simpli
# emerg: act, heart, begun, skill, deep
# promi: third, shift, embarrass, voic, famili
# karzai: ford, came, husband, carter, name
# known: similar, player, confront, attempt, ideolog
# difficult: differ, big, seriou, kind, far
# mtg: avail, kouchner, potu, sept, travel
# jack: ms, readout, pj, raj, noon
# tax: factor, inevit, tend, count, constitu
# advanc: restor, britain, encourag, remain, seek
# blackberri: wireless, judith, xpress, melann, hrc
# central: environ, western, transit, author, arm
# billion: increasingli, buy, regul, maintain, account
# break: perhap, woman, record, clegg, abov
# black: rare, defeat, rever, lawmak, unanim
# civil: growth, sustain, expand, threat, societi
# citizen: partner, capabl, threat, histori, restor
# etc: cuba, elsewh, saudi, ea, water
# korea: africa, north, reconstruct, mexico, sri
# old: mile, rove, deed, suddenli, woman
# agenc: agricultur, includ, local, educ, oper
# publish: samuel, band, max, patrick, columbia
# land: oversea, hama, standard, disast, saudi
# abedinh: jul, millscd, sep, nov, reinesp
# board: site, ran, ceo, frequent, web
# fall: suddenli, guardian, old, branch, rove
# reflect: heart, act, shift, will, emerg
# miss: mention, love, wjc, deadlin, meantim
# moment: whatev, meant, short, answer, word
# warn: outsid, often, voic, attempt, lie
# charg: seemingli, endor, skousen, angri, birch
# particularli: terrorist, measur, seek, essenti, safeti
# readi: everyon, wo, tell, excit, love
# pakistani: busi, palau, vision, kenya, pursu
# legisl: unlik, fail, convinc, fair, frustrat
# whose: tension, sought, massiv, investig, donor
# specif: certain, bad, explain, alreadi, path
# jame: convent, jefferson, dean, massachusett, lawrenc
# measur: terrorist, particularli, mandat, essenti, demand
# express: despit, argu, contrast, consist, opposit
# option: choic, tough, expect, instead, suggest
# budget: near, separ, monitor, main, refug
# learn: awar, oversea, propo, watch, elsewh
# deni: interv, counterpart, forum, marin, russian
# sorri: messag, best, read, catch, tonit
# refu: unionist, trend, defeat, margin, highli
# attend: mcc, kevin, yu, carolin, gration
# cover: impress, observ, tone, watch, ignor
# probabl: find, someth, still, thought, ca
# themselv: avoid, intent, larger, coalit, money
# everyth: explain, alway, noth, everybodi, possibl
# attempt: radic, known, warn, embrac, shown
# prioriti: resourc, invest, mission, throughout, personnel
# target: declar, analyst, cultur, employ, corpor
# weekend: anytim, ok, earli, check, shaun
# coalit: shape, cut, themselv, fact, avoid
# cau: soldier, zionism, cut, beyond, cost
# previou: brought, allianc, lie, reject, koch
# although: translat, carri, stop, perspect, style
# wait: tonit, stuff, feedback, list, fine
# cost: implic, weaken, faith, simpli, form
# host: summit, mexican, televi, retir, mark
# evid: deserv, insist, stake, neg, frustrat
# led: launch, conduct, manag, revolutionari, armi
# protest: similar, radic, equip, known, sexual
# confid: success, defin, allow, demand, signif
# began: ralli, depict, secret, hire, imag
# solut: must, valu, respon, futur, problem
# signif: demonstr, play, allow, trust, compromi
# british: agent, haqqani, gay, asia, japan
# danger: fear, lack, young, consequ, instabl
# short: whatev, yet, exactli, moment, stick
# palin: favor, ganley, portman, margin, bipartisanship
# studi: school, youth, journalist, media, applic
# appoint: spokesman, nsc, jone, weekli, remark
# terrorist: measur, particularli, essenti, taliban, accept
# dialogu: clip, kim, rodriguez, landler, suit
# beyond: soldier, larger, attent, depend, ground
# influenc: encourag, danger, particular, lack, improv
# haitian: feder, terror, establish, across, environ
# associ: fellow, african, advisori, scientist, fellowship
# appar: behind, appear, charact, cathol, stanc
# sheet: confirm, op, yang, schedul, anytim
# front: stress, therefor, disast, escap, regim
# r: sat, pat, doug, capricia, dec
# cooper: tunisia, enhanc, border, infrastructur, ngo
# research: professor, energi, waziristan, endur, studi
# pay: condit, depend, compromi, principl, area
# attach: pj, derek, follow, note, dan
# bureau: fellowship, conven, strateg, shadow, consular
# object: basi, chine, technic, enemi, action
# paper: rich, eric, lou, yellow, iii
# becam: promin, openli, combin, divid, trillion
# eu: interior, tenur, behalf, missil, contradict
# individu: level, trade, activ, increasingli, domest
# valmoro: ecial, lona, joann, fuch, shuttl
# nomin: governor, taitz, lobbyist, freshman, caucu
# intellig: armi, expert, manag, indian, led
# sbwhoeop: pverveer, hume, sbwhoeor, aug, vermarr
# robert: breakfast, suit, powel, seci, dean
# colleagu: seri, quot, peter, consult, abba
# contribut: partnership, compani, establish, terror, muslim
# invit: rich, lowey, lou, eikenberri, clair
# obviou: mind, answer, whatev, alreadi, explain
# valu: greatest, respon, toler, solut, effect
# attent: rather, ultim, basi, chine, intent
# anyon: might, chanc, someth, feel, still
# libyan: reserv, struggl, jerusalem, doctrin, moral
# c: slaughter, afb, fuch, hotel, renaiss
# border: enforc, ngo, infrastructur, volunt, civic
# trust: demonstr, weak, signif, deserv, evid
# pressur: young, battl, gain, wage, consequ
# brother: sarkozi, match, openli, mount, provinc
# wish: stuff, glad, followup, explor, miss
# andrew: tail, airport, afb, francisco, lewi
# seat: prefer, filibust, gop, amend, rare
# recommend: quick, touch, ill, roll, remind
# languag: insist, theme, interpret, treat, neither
# risk: area, condit, life, avoid, violenc
# al: televi, shah, cia, assassin, roosevelt
# spent: eight, almost, nine, six, second
# soldier: ground, fear, cau, suffer, beyond
# declar: reject, palau, freeli, target, determin
# main: consult, born, forum, pick, ran
# energi: perman, humanitarian, curb, revolutionari, north
# everyon: readi, prepar, wo, love, feedback
# greater: religi, feder, reduc, across, freedom
# climat: comprehen, europ, un, uniqu, impo
# rest: alon, goe, frame, judgment, altern
# asia: regard, british, thinker, africa, near
# lauren: tuesday, hrc, monday, sent, jiloti
# accu: cite, captur, dutch, nazi, atmosph
# ahead: onc, obviou, knew, short, place
# vice: former, senior, top, biden, georg
# assum: bit, decid, yet, someon, guy
# hotel: ppl, luncheon, marriott, sharon, recept
# burn: jeff, carlo, bob, ben, min
# employ: cultur, femal, intensifi, maintain, target
# page: receiv, chat, calendar, tv, apolog
# russia: lesson, relief, appli, model, assess
# popul: highest, prevent, taliban, increasingli, reduc
# watch: tone, pull, observ, titl, impress
# origin: hospit, kindl, headlin, larri, clerk
# version: dodd, durbin, rob, cr, overnight
# natur: histor, improv, desir, religion, equal
# camera: prece, marshal, approx, bilat, spray
# nearli: reformist, dozen, reput, fiscal, ohio
# network: polic, modern, islam, belief, recoveri
# sound: anyway, stori, pretend, anybodi, worth
# rice: visit, mom, team, met, congratul
# carri: although, surviv, pattern, bare, prove
# longer: succeed, quickli, push, theme, neither
# opposit: battl, express, convinc, rival, healthcar
# western: train, function, arm, guard, arsen
# consult: ran, seri, foster, forum, interv
# essenti: taliban, particularli, skeptic, measur, terrorist
# partnership: establish, contribut, program, larg, organ
# worth: ourselv, bad, alon, guess, rain
# bad: wrong, alreadi, obviou, specif, ourselv
# five: six, three, lost, eight, least
# shift: reflect, famili, lay, third, present
# appropri: departur, chamber, rangel, husband, took
# wall: island, maquiladora, mall, italian, australia
# form: simpli, faith, cost, tactic, devolut
# encourag: credibl, deepli, substanti, influenc, britain
# cultur: maintain, femal, hunger, perform, rang
# commiss: fbi, south, campu, moham, attorney
# implement: individu, terror, activ, initi, creation
# popular: primari, inten, control, attack, reput
# touch: sleep, recommend, remind, enjoy, holiday
# exist: suffici, ground, soldier, ultim, statu
# product: transpar, zionist, consum, poor, suffer
# chairman: capitol, headquart, baker, massachusett, lesli
# invest: resourc, prioriti, personnel, throughout, mission
# summit: host, mexican, televi, island, steven
# despit: contrast, express, consist, lie, transform
# assembl: insid, analysi, introduc, promin, exten
# handl: healthcar, fail, ahmadinejad, qualifi, seventi
# grow: seek, credibl, particular, enabl, restor
# honor: audienc, deni, wisdom, russian, brazil
# argu: express, determin, contrast, despit, undermin
# victori: uup, mp, fallen, unionist, dup
# joint: prece, benjamin, room, bilat, beast
# charl: ed, portray, hitler, jane, blue
# expert: latin, armi, indian, intellig, manag
# tabl: carleto, closer, extend, door, parent
# condit: violenc, risk, natur, depend, area
# dan: add, follow, wi, kurt, derek
# directli: translat, empha, although, pattern, stop
# game: extend, singl, mix, damag, somewhat
# class: bar, villag, academi, contributor, juarez
# conduct: launch, donor, led, wide, corpor
# insist: languag, badli, succeed, neither, revolut
# whole: statu, symbol, basic, cau, powerless
# choic: fair, instead, howev, record, beat
# track: reaction, tree, anyway, pain, detail
# kennedi: henri, alan, mari, blog, bauer
# ny: dinner, dai, qatari, shuttl, jacki
# worker: earn, bodi, founder, legal, fee
# biden: georg, advi, aid, mahmoud, netanyahu
# nato: indian, treasuri, expert, african, humanitarian
# uup: mp, perhap, dup, victori, clegg
# father: die, sarkozi, dream, stanc, son
# faith: simpli, cost, form, devolut, over
# demonstr: signif, deserv, trust, biggest, hurt
# construct: impact, tradit, maintain, rang, renew
# constitut: reli, femal, consul, blame, argu
# french: lieberman, audienc, seri, facebook, peter
# activist: industri, becam, spread, claim, faction
# principl: involv, consid, goal, advanc, terrorist
# murder: sexual, art, regim, rape, disast
# coupl: miss, mention, stori, deadlin, anyway
# disapprov: approv, trend, ahmadinejad, palin, conserv
# wo: excit, love, sound, readi, everyon
# expand: promot, empow, civil, establish, feder
# chri: outlin, spoken, bahtiyar, ass, conver
# defeat: minor, black, refu, trend, fallen
# religi: greater, presenc, food, attract, regul
# centuri: particularli, terrorist, histori, respect, seek
# woman: eye, suddenli, gap, light, old
# hundr: militia, lower, stimulu, prospect, rural
# document: walk, materi, desk, memori, truth
# remind: ill, holiday, sleep, okay, touch
# gaza: insurg, commerci, competit, disabl, oil
# joe: david, hagu, jone, panetta, donilon
# extrem: tactic, wage, gain, desir, consequ
# text: page, tomicah, apolog, inr, comment
# amend: swing, victori, rare, younger, repeal
# jew: soldier, cash, suffer, suffici, christian
# light: gap, eye, carri, surviv, bare
# sit: shot, mccain, gave, dress, amid
# skousen: strike, eventu, charg, art, bodi
# separ: alleg, player, investig, craft, conclud
# lunch: conf, cell, monica, mitchel, avail
# personnel: worldwid, resourc, collabor, invest, guard
# slaughter: c, afb, ceremoni, astoria, renaiss
# gore: phrase, cameron, indic, appear, doubt
# prefer: seat, unfortun, amend, rare, unanim
# analysi: insid, assembl, divid, isol, replac
# half: six, nine, fifti, fallen, unlik
# chair: staffer, commerc, congressman, michigan, oak
# legal: suppli, exchang, destroy, medic, draw
# child: market, destroy, destruct, abu, earn
# recogn: freeli, conclud, resolut, analyst, declar
# plane: cancel, add, wh, list, kurt
# rise: domin, theori, anger, combin, eventu
# identifi: minimum, escap, germani, collect, crimin
# mind: obviou, answer, save, meant, line
# mayor: czech, shah, assassin, al, rubin
# die: dream, son, father, dynasti, storm
# period: emot, propo, deliv, welcom, tone
# stage: observ, procedur, pull, stop, imposs
# pentagon: advisor, top, fellow, execut, baker
# benefit: fundament, ingo, area, process, digniti
# background: materi, flag, document, overview, wonder
# over: rel, calcul, factor, hurt, elector
# sometim: return, paper, invit, kirk, mcguin
# uk: leak, cnn, blumenth, davi, usa
# drive: foggi, head, church, eca, mexico
# tough: suggest, expect, surpri, option, stuck
# gone: respond, hang, door, anticip, pretti
# basi: chine, attent, ultim, object, intent
# entir: paid, prison, cathol, loss, bear
# journalist: gulf, veteran, harvard, scholar, youth
# abov: felt, averag, canada, full, inevit
# goe: altern, door, unless, respond, rest
# session: toni, town, jone, donilon, met
# cent: per, honest, littl, wor, though
# germani: collect, suffer, mutual, identifi, regim
# true: god, sort, save, realiti, listen
# youth: compound, cancer, instrument, harvard, journalist
# district: de, prior, florida, joseph, artist
# mexico: eca, eastern, wall, africa, approxim
# defin: confid, success, demand, allow, goal
# edit: info, read, ye, pl, traffic
# madam: outer, hillari, krishna, rodham, press
# mike: min, bob, nea, brian, shannon
# lose: over, tori, rel, argument, test
# welcom: period, excel, propo, elsewh, document
# urg: abandon, socialist, era, dismiss, secret
# domest: element, level, taliban, individu, grow
# melann: ft, judith, laszczych, jacki, blackberri
# min: nea, bob, margaret, video, mike
# site: ceo, board, web, soviet, ran
# remov: ticket, wear, echo, llosa, sister
# surpri: tough, second, stuck, perfect, expect
# palau: declar, pursu, vision, collabor, elit
# ten: weiner, scandal, trial, quarter, colleagu
# safe: creativ, worth, bibi, track, rain
# trend: margin, refu, ahmadinejad, defeat, parliament
# determin: argu, declar, situat, vision, struggl
# growth: sustain, civil, law, threat, reduc
# cell: fli, conf, lunch, potu, wha
# consist: despit, failur, contrast, fighter, express
# heart: therefor, reflect, collect, student, desper
# court: rape, confin, draw, teen, drawn
# toni: session, town, donilon, sec, video
# unfavor: favor, hrd, hvn, dem, ganley
# water: rock, tour, saudi, heavi, jose
# certain: necessari, path, outcom, specif, alreadi
# environ: central, author, feder, terror, haitian
# maintain: cultur, struggl, threaten, counterinsurg, deepli
# total: rural, charg, provinc, birch, mount
# paul: co, jonathan, king, daniel, webb
# clearli: stand, bring, ever, underscor, quickli
# integr: gender, oper, servic, hemisph, perman
# primari: popular, centrist, reput, blame, nearli
# kabul: admir, met, princip, spring, head
# rang: capit, design, impact, corrupt, tradit
# mayb: fine, wjc, deadlin, stay, touch
# market: regim, grant, destroy, child, euro
# robinson: friend, amaz, came, empey, name
# wrong: alreadi, bad, mind, path, obviou
# simpli: form, faith, hurt, cut, cost
# spray: franklin, prece, madison, camera, benjamin
# near: born, refug, statist, budget, missil
# avoid: themselv, risk, shape, depend, coalit
# reagan: silent, scientist, citi, advisori, outfit
# reid: nowakowski, rahm, chamber, udal, harri
# sustain: growth, law, civil, threat, settlement
# purpo: qualiti, heart, attempt, pattern, prove
# minor: defeat, liber, reformist, ohio, turnout
# son: storm, blow, die, dog, wit
# race: tauzin, phrma, takeov, rangel, lawmak
# seri: peter, colleagu, quot, consult, abba
# practic: road, sudan, sort, surviv, latter
# fire: unusu, dead, crowd, dog, weiner
# tradit: design, capit, rang, occupi, impact
# oil: theori, gaza, capit, destroy, eventu
# prece: camera, franklin, joint, spray, benjamin
# info: edit, read, ye, traffic, nice
# brought: reject, previou, outsid, warn, similar
# jeff: burn, ben, birthday, carlo, campbel
# throughout: facil, un, task, larg, structur
# drop: peter, demint, scott, retir, retreat
# bomb: declin, green, conspiraci, detain, empir
# exchang: legal, medic, asset, franc, destroy
# resolut: zone, recogn, palau, tradit, collabor
# secret: depict, abandon, crowd, imag, cite
# capac: afghan, commun, arab, iran, organ
# reserv: dictat, advoc, doctrin, moral, corrupt
# lobbyist: caucu, emanuel, nomin, governor, taitz
# clip: gala, blake, feltman, landler, norwegian
# written: correct, hit, brussel, recal, chelsea
# drug: domin, militia, theori, resent, territori
# donor: investig, massiv, conduct, communist, whose
# rich: lou, paper, craig, yellow, invit
# deleg: princip, eu, head, small, spokesman
# common: rule, skeptic, attitud, demand, highest
# career: current, british, ambit, agent, deploy
# indic: beat, boost, recess, younger, perhap
# mother: window, shot, dress, rush, formal
# guard: function, arm, counterterror, western, train
# histor: natur, desir, abort, soft, devolut
# frustrat: neg, fair, brand, politician, realiz
# certainli: alway, sen, noth, everyth, narr
# struggl: maintain, deepli, encourag, credibl, undermin
# outer: press, beast, room, joint, madison
# gain: tactic, wage, extrem, pressur, rel
# bottom: vietnam, tour, shop, judg, cnn
# thousand: wave, bodi, detent, rural, birch
# colleg: boston, founder, arizona, mountain, villag
# necessari: path, certain, symbol, sort, god
# six: eight, three, half, five, nine
# wonder: flag, enjoy, okay, folk, background
# provinc: meanwhil, oppon, total, endor, seven
# paid: entir, prison, kept, convict, qualiti
# ed: charl, blue, portray, web, soviet
# healthcar: convinc, deficit, unlik, seventi, gain
# spokesman: nsc, appoint, kentucki, princip, mel
# ...
# treari: seiji, russel, svc, qureshi, shoreham
# baathist: westen, shrug, reed, manuel, throat
# marko: espersen, qureshi, halevi, natalegawa, rl
# ofth: sporad, hapless, prayer, safe, apec
# saad: massachusett, suit, tbd, potomac, avenu
# throe: later, finish, hour, bang, stay
# airlift: wohler, illicit, nonsen, wol, hypocrisi
# motorola: volcan, bereft, piti, infantryman, deepen
# jalal: kitutu, univ, institut, shamata, multilat
# admn: piquant, ziyang, gladi, perish, millennia
# nuni: convent, jame, fellowship, street, huntsman
# kamal: berlusconi, creditor, columnist, jordanian, olmert
# guiliani: intercept, kurdish, anem, thrush, tuv
# imperfect: cap, exit, sabotag, alley, likud
# luer: ood, oclo, oman, iphon, hetet
# confirn: vairnoro, agoa, ukr, datuk, bolivia
# tramsform: b, fyi, rc, sid, typo
# theirvoic: backward, forward, thing, veri, think
# barzilai: pm, westerwel, papa, cay, hyatt
# renwick: wermarr, hirofumi, lautenberg, fvv, loi
# miroslav: net, sting, float, axelrod, wartim
# lajcak: para, comment, luck, exec, piec
# efrat: hvn, caucasian, theolog, worn, evnglcl
# riskin: stock, muammar, charl, judiciari, rose
# barkat: rou, french, regard, contradict, lieberman
# undivid: redefin, boom, foundat, homeland, creation
# lawov: icao, sheraton, westchest, tliet, elliott
# hfac: toiv, balkan, verveer, contact, oral
# roe: emin, businessweek, swift, commut, sanit
# testfi: glacial, havisham, hidebound, ingrain, jungl
# uninform: ming, wilson, blog, ceo, reportedli
# tabachnick: oprah, revi, finish, late, earli
# lovefest: resid, hunan, en, afb, rout
# tilden: afb, aviat, andrew, laguardia, kuwaiti
# litmu: region, global, unambigu, issu, mobster
# nra: world, interest, china, human, america
# plainer: outbreak, seem, onli, smell, even
# gabi: odierno, seventh, unawar, affair, pacif
# eucom: simmer, workweek, plainspoken, quantiti, dri
# powerpoint: lift, distribut, background, materi, verbal
# ry: newmyer, interview, ac, judi, glover
# blazon: wirajuda, auspic, fayyad, current, privaci
# horrend: blasphem, roughli, shortag, breath, high
# enuf: ipad, fyi, typo, iphon, sid
# bldg: scolarship, rianistan, preparatori, secondari, gladi
# scolarship: millennia, bldg, beyrl, expropri, amidst
# jaunt: raucou, proteg, mccaughey, lauri, medvedev
# ashkelon: spray, madison, monro, luncheon, ppl
# swo: mcdonough, carter, struck, owner, cloth
# councilor: depart, nw, bowen, arriv, doc
# amato: vilsack, odein, emeritu, foreign, prime
# saleo: sincer, wisner, kathleen, interior, convoy
# correir: obsolet, tamil, cybersecur, musavi, policymak
# repubblica: innov, entrench, amo, traffick, prohibit
# sabafi: madison, room, beast, spray, monro
# sabah: spray, franklin, madison, prece, camera
# inspiron: spill, screen, messi, ari, kippur
# pavillion: fatah, tyrann, hyster, villain, amnesti
# nam: westerwel, menon, est, fm, rm
# radoslaw: qureshi, seiji, prep, amr, alejandro
# tamn: schedul, kouchner, w, updat, sheet
# bingguo: stint, iglesia, rodriguezm, quadrenni, memorandum
# amembassi: wheel, cathedr, lb, brian, wendi
# samareh: fountain, moham, denounc, roosevelt, pole
# zohra: ust, ipad, iphon, sid, janua
# pyramid: irrelev, phenomenon, jobless, puni, moratorium
# rajapaksa: dh, prep, einhorn, heck, oval
# ansuncao: job, term, alien, less, fight
# afonso: arn, eni, gideon, chariti, sach
# jiangsu: boycott, ailic, crowley, philip, cabal
# mrisho: joint, room, monro, madison, staff
# taix: hebrew, nexu, tyrann, reconstruct, breakout
# liddl: murtha, disco, mcgovern, churn, cot
# yuyuan: knight, armagh, profess, suck, sharpli
# inextr: bring, loophol, drastic, condon, everybodi
# beatric: wolf, rooney, costa, colin, harnish
# gram: dh, qureshi, guido, prep, espersen
# hashemi: brainard, overtur, johnson, facebook, municip
# noncommitt: ador, wither, synchron, wobbl, gaylord
# tumen: andrew, slaughter, afb, tliet, c
# buffer: committ, dept, build, whichev, member
# ypu: aclb, dardick, reax, essayist, briefin
# leguen: work, rankl, togeth, around, milk
# millennia: expropri, piquant, dandi, perish, expressli
# oipen: set, trip, unga, speak, soon
# dd: robe, denial, fit, excu, mechan
# dissolut: protector, prosecut, sieg, api, primarili
# insolubl: redact, inform, sensit, foia, waiver
# berm: explo, glass, outburst, belfast, footag
# benn: usa, hospit, star, clerk, sam
# aluf: allen, abraham, unsprit, il, layer
# html: rupert, reuter, jfm, pray, ryan
# lumen: richert, pimp, philip, san, suu
# voluntarili: scari, assuag, dispel, smallest, needless
# conor: got, sorri, footbal, reconven, predica
# doabl: lu, hype, sarajevo, profan, worthless
# wildlif: chart, altho, great, foolish, definit
# machinist: undersec, mishap, uiveasccib, philippin, ingredi
# allay: thatyou, weisel, tshirt, unansw, commentariat
# cavali: unrel, grain, entertain, strongest, uncl
# matrinez: packer, wexler, verstandig, aug, pverveer
# mejann: slope, zhou, reproduc, v, onlin
# tiresom: lieberman, embassi, egyptian, bangladesh, swedish
# ahem: wsj, degnan, treater, mill, wpost
# najaf: unsuit, brain, margin, wtbrnagn, birther
# grise: caucasian, aura, hometown, impun, academia
# taxi: hello, isabel, cancel, revi, weigh
# databa: plouff, estrang, herebi, geniu, recur
# tonic: address, safe, tapper, eleph, bibi
# ursula: brf, jerri, straley, ife, zi
# pronounci: erik, chen, njj, howe, troublemak
# silvia: hong, prophet, outdoor, sl, markezi
# precursor: bug, braval, js, unveii, philand
# hambi: einhorn, acheson, wiretap, davutoglu, brief
# arellano: natalegawa, press, pool, heidi, pm
# evangelin: xxii, literatur, ridicul, dental, spine
# anticlimax: federalist, dire, funder, mute, riski
# paltri: alik, affili, graver, flaw, young
# postmodern: uncondit, kieffer, rightwinq, detract, srr
# burnswj: tember, sbwhoeop, quam, pverveer, steinbergjb
# millsl: rn, alloy, degnan, kientuiri, mccaughey
# patricio: wholli, nile, arrang, encount, wow
# qfr: adlerc, gate, chief, staff, oval
# blden: bioethicist, chief, seventh, former, mehmood
# farr: honest, screen, reader, hung, simpl
# niki: honest, firmli, cent, conc, per
# tsonga: ireland, minimum, statu, inspir, palpabl
# matsui: mention, pain, anybodi, anyway, rough
# suichbaatar: drc, truli, specif, adapt, sen
# batbold: whi, doe, way, ought, feel
# sleepi: commemor, yossi, slate, chach, mustafa
# opaqu: predat, concret, bashir, distort, meant
# che: wd, let, know, discuss, talk
# smokescreen: furthermor, ugli, gladli, confu, wrong
# rola: around, appreci, crise, wealth, togeth
# dashti: poss, piqu, zamora, owen, tnr
# narcotraffic: disclo, linger, lindsey, licen, rumour
# vendor: correct, nail, friend, left, amaz
# rampag: excit, idea, keep, altho, ca
# moo: dine, hart, dirksen, oval, chief
# industria: tsunami, divin, formaldehyd, luntz, distinct
# youssef: henri, turner, roger, pih, carl
# golub: mustafa, fellowship, center, associ, tn
# leonard: nyu, club, e, uss, st
# leo: shapiro, gala, aung, theater, landler
# romou: suu, longtim, william, cvc, thoma
# colonia: oklahoma, fink, dawn, newspap, parthenon
# shea: amp, windrush, sheldon, isfahan, razavi
# standish: denver, washington, hotel, jame, spray
# featureless: incarc, upload, denver, tn, advisori
# mumuni: lot, much, question, well, realli
# valdi: gregori, auditorium, biweekli, pmsecretari, mla
# zatler: unforgett, pmsecretari, interview, scrub, pari
# triomph: az, medium, razavi, adult, emori
# treatyorgan: spray, monro, ppl, madison, franklin
# replica: aipac, staf, interv, consult, counterpart
# ham: beacon, toivnf, philip, mail, crowley
# campestr: sp, patrick, jacquelin, jo, danni
# condominium: romania, mckinley, tamil, dump, alloc
# briefin: swane, obey, jefferson, mcpherson, goosbi
# pranab: rudd, privaci, ashfaq, egyptian, swedish
# kumar: jassim, ret, hottest, cg, beller
# mukefu: hungarian, telcon, copyright, goldston, inquir
# jumbl: secondli, custom, austrian, knee, explan
# amsecretari: thai, ashton, danni, video, conf
# pmweekli: petraeu, cabinet, autumn, brown, mr
# pmoval: vice, former, butt, senior, biden
# footstep: rendezv, baton, revlon, lamin, rex
# tamper: dvf, clotur, version, anali, sarah
# unclaim: workabl, unfamiliar, surpasseth, golden, staunch
# maal: rome, k, kohgiluyeh, mari, dunn
# manifestli: exil, sinn, viewer, symptom, scath
# ambassadorship: hoge, amen, get, wd, go
# vuant: oman, quint, krystal, rejkavik, luer
# krauthanun: peacetim, whoop, civiliz, puriti, refut
# ghfsi: nita, mckay, legendari, congrat, uruguay
# gni: memcon, chappaqua, wi, follow, note
# lat: nighttim, yousef, hillel, bk, pul
# qua: inflow, mcculley, hoard, edg, inher
# dov: humanist, unproduct, loudest, ustr, unscr
# sine: social, bank, feder, poorest, expand
# perimet: salt, dia, mil, affidavit, shoreham
# trident: nose, stockpil, insecur, hike, sd
# adumim: mapi, gorgeou, sbu, huffpost, bin
# thatyou: tshirt, reallli, themat, skyrocket, backward
# ctthe: cargo, covert, pant, tower, marathon
# americanist: steven, commemor, belov, christoph, professor
# europeanist: colombia, hub, port, argentina, copyright
# consumm: haftar, secur, afghanistan, govern, develop
# krauthamm: blink, understat, multipli, timefram, quit
# thatcherit: glimp, packag, foot, belfast, indign
# disapora: nephew, fodder, appea, furi, visual
# googler: sure, ni, jm, good, resend
# mubarek: nyu, columbia, crane, club, amp
# midwiv: strateg, albright, muasher, endow, christoph
# sebiliu: next, earlier, accustom, pass, anoth
# ripley: shrug, iaa, persua, bottom, courtney
# sece: ai, button, wol, final, rep
# ghazi: advisor, lisbon, execut, top, advi
# sprout: huey, schiller, sashkavilli, jesuit, hoo
# lacey: magazin, grand, loui, kiss, terri
# ramo: escort, ceremoni, luncheon, franklin, spray
# pynoo: fin, westerwel, pm, anteroom, iqbal
# decompo: withstand, scath, sim, chatter, kurdestan
# tin: jackson, spain, tim, garden, corn
# corrug: spark, lawyer, pace, insult, bar
# fape: hale, monday, wrote, sunday, tuesday
# hodgepodg: controversi, broken, evacu, offen, field
# netenyahu: barb, lisa, rs, raiser, han
# ramshackl: spain, height, arc, wilson, bloomberg
# poit: fox, mandelson, microsoft, beach, clerk
# thessin: nichola, king, paul, ted, daniel
# harnish: marc, nick, file, coat, pen
# seiva: harold, huffpost, tv, geneva, articl
# salahuddin: clown, cave, socialist, tout, interior
# squalor: drink, blank, trace, caught, googl
# shrub: jay, mcconnel, frank, rupert, n
# tilleman: julia, vernon, clearanc, va, kermanshah
# boomtown: trustworthi, burm, stimul, wealthiest, vocat
# tia: analyz, pretext, anthropologist, irrig, bfzndn
# stith: merchant, la, weather, port, shop
# mcguiness: packer, goad, monday, lautenberg, hale
# ditech: intel, lighter, heartfelt, veget, nevada
# annenberg: beer, ghani, offend, sister, twice
# nyamlel: accur, strictli, elia, gaug, ii
# olath: fernandez, photo, weekli, seci, pmsecretari
# winni: noam, thunder, tuv, ardebil, iileg
# talal: parker, dunn, charli, nichola, salon
# cromarti: energi, monetari, vital, revolutionari, innov
# cassidi: jo, smtp, correspond, moin, url
# disinvit: ariel, conven, dialogu, bilat, bureau
# wist: egg, likelihood, persist, intraven, disrupt
# coverup: scandinavian, rampant, fatigu, subsidi, lapid
# covarrubia: toll, sodini, minu, swept, mysteri
# soledad: contain, discov, electr, evoc, googl
# shapleigh: chihuahua, usaid, disorgan, drive, deft
# donnelli: backyard, unfussi, nonprofit, sharia, caveat
# katherin: rker, bfzocfyb, arcana, retaken, farar
# gutierrez: hv, drama, inaugur, surrog, cath
# regreso: googl, guantanamo, hondura, accid, lean
# marisela: licenc, angola, garden, incompet, bloomberg
# incipi: sue, ismail, elvi, huffpost, amcit
# loach: health, destabili, pragmatist, rubbl, reform
# craighil: blockad, perplex, cent, strive, per
# strewn: scream, jesu, mccain, itali, wife
# jaramillo: rio, rebuk, blue, secretli, mainli
# paiavera: deleg, princip, albright, trilat, baghdad
# tomorow: transmit, fyi, rolodex, lang, saif
# denot: former, advisor, butt, subcommitt, aorta
# asterisk: pentagon, scientist, advisor, sharehold, baker
# wan: format, manag, particip, assert, financ
# departst: question, put, agr, togeth, end
# rebeld: nafta, illib, starv, spine, fal
# bland: mileston, pessimist, contest, end, quit
# ontivero: teed, estonia, getlin, hmm, ith
# rivera: dunn, freddi, river, claudia, idiot
# chemist: tbd, th, breakfast, suit, loung
# candlehold: cochran, shot, sit, angl, moscow
# munoz: browner, dominican, chico, driver, purg
# yvett: hayek, marvin, conni, soro, pao
# ru: cnpc, apparel, charter, colleg, founder
# citywid: arthur, hebrew, instil, nexu, reconstruct
# lavrovirussian: bikini, mtp, sikorski, nakason, kim
# luz: channel, earthquak, kay, pictur, feed
# indio: su, nixon, attorney, woodrow, commerc
# mesa: azerbaijan, lake, allen, img, bauer
# morelo: introduct, va, marmara, de, shoe
# coionia: gari, hidden, allen, mari, park
# hovel: engel, expo, mark, dawn, newspap
# painter: govt, grate, otherwi, salut, flag
# jpn: embassi, honor, polish, deni, retreat
# kor: mobil, wisdom, rigid, flood, reidel
# chn: underlin, conclud, immen, recognit, begun
# japen: occupi, impact, capit, manner, pour
# candlelight: publish, hannah, band, max, haaretz
# comfirm: dod, applianc, thinker, acquir, fiction
# crosbi: ricardo, log, buffet, ty, bn
# paniagua: drawn, engin, adver, atheist, disabl
# mariela: sieg, vacuum, hardlin, latter, examin
# indol: har, settler, manipul, fuel, competit
# diamondstein: brain, sadli, ineffect, dede, masturb
# ivett: turner, windrush, sistan, joseph, florida
# bonfir: wear, cheer, master, peru, chronic
# coffin: flood, worldview, punch, shrug, fun
# altar: hyatt, quam, canahuati, est, verveerm
# muerto: pool, pm, rm, verveerm, marti
# sophocl: pr, headlin, jagger, qazvin, peru
# latif: jersey, roger, herald, miami, lieuten
# lendingtr: rarrot, kientuiri, realism, sixtieth, vandal
# gomez: headlin, music, desk, abramoff, memori
# sked: weasel, sanctiti, irrepar, disjoint, anyth
# slash: vs, basin, casu, platitud, apounc
# slighter: muddl, ador, trembl, freez, enthusiasm
# chiapa: per, cent, niki, firmli, honest
# rca: diplo, jockey, tall, qaddafi, kurdistan
# ej: trigger, parochi, hudson, partial, sail
# delphi: grave, sharpli, underway, hor, guilti
# aberr: ruler, grab, virul, leban, matern
# puta: dissen, simplist, outbreak, themat, peopl
# scrambl: physician, kordestan, monthli, wear, scowcroft
# ssue: caveat, soil, haggl, fate, peacemak
# fluoresc: qazvin, likin, ilam, khuzestan, mao
# orig: prom, precipit, syria, vanderboegh, chet
# sync: tell, give, trip, everyon, thought
# mexicano: cook, moment, fuck, stick, whatev
# nike: fco, stakehold, ngo, variou, model
# braulio: ea, etc, land, cuba, grate
# desol: christian, bircher, orthodox, shore, zionism
# taper: alumni, venezuela, bangladesh, angela, mike
# harrington: powel, columnist, robert, colin, liaison
# cifrino: chatham, coll, nocol, inquisitor, audrey
# receip: publish, samuel, kiss, url, band
# boutiqu: belgium, mo, iaea, mussolini, avenida
# bambi: verveer, lona, valmoro, melann, laszczych
# felic: hoover, abdel, annual, premier, william
# gaer: spector, promptli, pt, poppi, hidden
# morin: bottom, von, dish, fattal, vietnam
# instituto: achil, specter, drama, tast, chip
# seguro: default, sweet, unhappi, show, moment
# narcotrafic: mental, tract, relev, decr, literatur
# maiimoud: wnice, svc, russel, odinga, pverv
# subset: vatican, contain, paranoia, clarifi, relev
# foregon: member, presidenti, bush, fumbl, cliqu
# aristocraci: polit, sway, degrad, public, american
# handcuff: ass, outlin, polish, formal, arrang
# bulletproof: nephew, sprang, philton, rosi, griev
# mand: falucca, dairi, tumult, spurn, ai
# wagon: fl, reid, pelosi, podesta, aliyev
# paddi: aliyev, fl, usss, moratino, kerri
# feebl: bloodsh, worn, patriot, wtbrnagn, paralyz
# madman: christma, ahead, default, surpri, show
# discussin: kuwait, jen, mini, schumer, richard
# conversatiion: footbal, osha, give, probabl, anyth
# maynez: hubert, jerri, applau, jon, rand
# prensa: deton, confidenti, articl, reynold, koh
# alejandra: l, et, wolf, patrick, tape
# sur: co, paul, cabl, ben, denni
# nort: cathedr, wheel, furnitur, arctic, salon
# frontera: kerman, flew, bloomberg, princ, shoe
# bloom: rooney, margaret, nea, editori, da
# technologico: campu, burma, commiss, golf, shah
# overgrown: philip, talbott, march, se, abc
# vett: capitol, counti, carolina, california, orang
# tdk: laguardia, youtub, season, lewi, aircraft
# nightclub: adl, england, mormon, medicin, manhattan
# amiga: reliev, santo, person, hardest, stride
# cano: bar, mod, alloc, nigeria, nur
# ixzz: dixi, mawr, travi, detect, rook

# %% [markdown]
# Non-Negative Matrix Factorization (NMF)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import NMF

# TF-IDF Vectorization
tfidf_vectorizer = TfidfVectorizer(stop_words='english')
tfidf_matrix = tfidf_vectorizer.fit_transform(lemmatized_text)

# Non-Negative Matrix Factorization (NMF)
num_topics = 5  # Specify the number of topics
nmf_model = NMF(n_components=num_topics)
nmf_matrix = nmf_model.fit_transform(tfidf_matrix)

# Get the top terms for each topic
terms = tfidf_vectorizer.get_feature_names_out()
top_terms_indices = nmf_model.components_.argsort(axis=1)[:, ::-1]
top_terms = [[terms[idx] for idx in row[:5]] for row in top_terms_indices]

# Display the top terms for each topic
for i, topic_terms in enumerate(top_terms):
    print(f"Topic {i + 1}: {', '.join(topic_terms)}")
# Out:
# Topic 1: fyi, fw, cheryl, millscd, high
# Topic 2: ok, talk, sound, thx, relea
# Topic 3: pm, thi, secretari, state, offic
# Topic 4: print, pl, pi, thx, copi
# Topic 5: ye, thx, work, lona, set

# %% [markdown]
# Topic Modeling (Latent Dirichlet Allocation - LDA)

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation

# Count Vectorization
count_vectorizer = CountVectorizer(stop_words='english')
count_matrix = count_vectorizer.fit_transform(lemmatized_text)

# Latent Dirichlet Allocation (LDA)
num_topics = 5  # Specify the number of topics
lda_model = LatentDirichletAllocation(n_components=num_topics, random_state=42)
lda_matrix = lda_model.fit_transform(count_matrix)

# Get the top terms for each topic
terms = count_vectorizer.get_feature_names_out()
top_terms_indices = lda_model.components_.argsort(axis=1)[:, ::-1]
top_terms = [[terms[idx] for idx in row[:5]] for row in top_terms_indices]

# Display the top terms for each topic
for i, topic_terms in enumerate(top_terms):
    print(f"Topic {i + 1}: {', '.join(topic_terms)}")
# Out:
# Topic 1: thi, work, wa, want, know
# Topic 2: wa, hi, ha, thi, obama
# Topic 3: thi, women, ok, need, work
# Topic 4: state, pm, depart, secretari, offic
# Topic 5: fyi, pm, cheryl, huma, fw

# %% [markdown]
# **(4) Temporal Analysis**

# %% [markdown]
# Investigate how email communications change over time.

# %%
import pandas as pd

# Assuming 'emails' is your DataFrame
emails['ExtractedDateSent'] = pd.to_datetime(emails['ExtractedDateSent'], errors='coerce')
emails.set_index('ExtractedDateSent', inplace=True)

# Resample data to daily frequency and count emails
daily_email_counts = emails.resample('D').size()

# Plot the daily email counts
daily_email_counts.plot(figsize=(10, 6), title='Daily Email Counts')
plt.xlabel('Date')
plt.ylabel('Number of Emails')
plt.show()

# %% [markdown]
# Visualization: The rolling average (take data from the past 7 days, add them together to get a total amount, and then divide that total by 7) gives the viewer an idea of how busy Clinton was over a week.

# %%
# Plot rolling 7-day average of email counts
rolling_avg = daily_email_counts.rolling(window=7).mean()

plt.figure(figsize=(10, 6))
plt.plot(daily_email_counts, label='Daily Email Counts')
plt.plot(rolling_avg, label='7-Day Rolling Average', linestyle='--', color='orange')
plt.title('Email Volume Over Time with 7-Day Rolling Average')
plt.xlabel('Date')
plt.ylabel('Number of Emails')
plt.legend()
plt.show()

# %% [markdown]
# Identify any patterns or anomalies in the volume of emails sent and received.

# %%
from scipy.stats import zscore

# Calculate Z-scores for daily email counts
z_scores = zscore(daily_email_counts)

# Define a threshold for anomaly detection
threshold = 3

# Identify dates with anomalies
anomalies = daily_email_counts.index[abs(z_scores) > threshold]

# Print dates with anomalies
print("Dates with Anomalies:", anomalies)
# Out:
# Dates with Anomalies: DatetimeIndex(['2009-06-16', '2009-07-02', '2009-07-14', '2009-07-25',
#                '2009-08-21', '2009-08-26', '2009-08-28', '2009-08-29',
#                '2009-08-30', '2009-09-01', '2009-09-12', '2009-09-20',
#                '2009-10-04', '2009-10-18', '2009-12-11', '2009-12-13',
#                '2009-12-22', '2009-12-23', '2009-12-24', '2009-12-29',
#                '2010-01-17', '2010-01-22', '2010-01-24', '2010-01-30',
#                '2010-01-31', '2010-02-06', '2010-02-08', '2010-02-10',
#                '2010-03-21', '2010-05-07', '2010-06-23', '2010-08-24',
#                '2010-08-26'],
#               dtype='datetime64[ns]', name='ExtractedDateSent', freq=None)

# %% [markdown]
# Correlate these with external events or timelines.
#
# Clinton served from January 21, 2009 to February 1, 2013. The dates with anomalies are all between August of 2009 and August 2010, with 7-day rolling average peaking around July 2009, January 2010, and August 2010. There are some major events, such as U.S. military campaign to take back Afghan Valley from Taliban force, Haiti earthquake in January of 2010, and winter storms in the East Coast that piled up to 40 inches.

# %% [markdown]
# **Overall Analysis**
# In this exploratory data analysis, we got a fairly good sense of Hillary Clinton's email communication, especially two aspects: time and people. We were able to discern the impact of events that impacted her policies by examining email volume over time and dates with anomalous email volume. In addition, by analyzing frequent senders and recipients, we were able to get an idea of how she interacted with her staff, politicians and others.
